# %%
from textblob import TextBlob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
## Tokenization
myfile = open('Alice_article_Wiki.txt', encoding='utf-8')

# %%
# Import txt file
with open('Alice_article_Wiki.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\\n', '')

# %%
# Sentence tokenization 

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)
print(tokenized_sent)
# Out:
# ['\n\n\n\nAlice\'s Adventures in Wonderland - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload file\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\n Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nBackground\n\n\n\n\nToggle Background subsection\n\n\n\n\n\n1.1\n"All in the golden afternoon..."\n\n\n\n\n\n\n\n\n1.2\nManuscript: Alice\'s Adventures Under Ground\n\n\n\n\n\n\n\n\n\n\n2\nPlot\n\n\n\n\n\n\n\n\n3\nCharacters\n\n\n\n\nToggle Characters subsection\n\n\n\n\n\n3.1\nCharacter allusions\n\n\n\n\n\n\n\n\n\n\n4\nPoems and songs\n\n\n\n\n\n\n\n\n5\nWriting style and themes\n\n\n\n\nToggle Writing style and themes subsection\n\n\n\n\n\n5.1\nSymbolism\n\n\n\n\n\n\n\n\n5.2\nLanguage\n\n\n\n\n\n\n\n\n5.3\nMathematics\n\n\n\n\n\n\n\n\n5.4\nEating and devouring\n\n\n\n\n\n\n\n\n5.5\nNonsense\n\n\n\n\n\n\n\n\n5.6\nRules and games\n\n\n\n\n\n\n\n\n\n\n6\nIllustrations\n\n\n\n\n\n\n\n\n7\nPublication history\n\n\n\n\nToggle Publication history subsection\n\n\n\n\n\n7.1\nPublication timeline\n\n\n\n\n\n\n\n\n\n\n8\nReception\n\n\n\n\n\n\n\n\n9\nAdaptations and influence\n\n\n\n\nToggle Adaptations and influence subsection\n\n\n\n\n\n9.1\nLive performance\n\n\n\n\n\n\n\n\n\n\n10\nCommemoration\n\n\n\n\n\n\n\n\n11\nSee also\n\n\n\n\n\n\n\n\n12\nReferences\n\n\n\n\nToggle References subsection\n\n\n\n\n\n12.1\nWorks cited\n\n\n\n\n\n\n\n\n\n\n13\nExternal links\n\n\n\n\nToggle External links subsection\n\n\n\n\n\n13.1\nText\n\n\n\n\n\n\n\n\n13.2\nAudio\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nToggle the table of contents\n\n\n\n\n\n\n\nAlice\'s Adventures in Wonderland\n\n\n\n94 languages\n\n\n\n\nAfrikaansAlemannischÃ†ngliscØ§Ù„Ø¹Ø±Ø¨ÙŠØ©Ô±Ö€Õ¥Ö‚Õ´Õ¿Õ¡Õ°Õ¡ÕµÕ¥Ö€Õ§Õ¶AsturianuAzÉ™rbaycancaà¦¬à¦¾à¦‚à¦²à¦¾é–©å—èªž / BÃ¢n-lÃ¢m-gÃºÐ‘Ð°ÑˆÒ¡Ð¾Ñ€Ñ‚ÑÐ°Ð‘ÐµÐ»Ð°Ñ€ÑƒÑÐºÐ°ÑÐ‘ÐµÐ»Ð°Ñ€ÑƒÑÐºÐ°Ñ (Ñ‚Ð°Ñ€Ð°ÑˆÐºÐµÐ²Ñ–Ñ†Ð°)Ð‘ÑŠÐ»Ð³Ð°Ñ€ÑÐºÐ¸BosanskiBrezhonegCatalÃ\xa0ÄŒeÅ¡tinaCymraegDanskDeutschEestiÎ•Î»Î»Î·Î½Î¹ÎºÎ¬EspaÃ±olEsperantoEuskaraÙØ§Ø±Ø³ÛŒFranÃ§aisFryskGaeilgeGalegoàª—à«àªœàª°àª¾àª¤à«€ðŒ²ðŒ¿ð„ðŒ¹ðƒðŒºí•œêµ\xadì–´Õ€Õ¡ÕµÕ¥Ö€Õ¥Õ¶à¤¹à¤¿à¤¨à¥à¤¦à¥€HrvatskiIdoBahasa IndonesiaInterlinguaÃslenskaItaliano×¢×‘×¨×™×ªà²•à²¨à³à²¨à²¡áƒ¥áƒáƒ\xa0áƒ—áƒ£áƒšáƒ˜ÒšÐ°Ð·Ð°Ò›ÑˆÐ°KurdÃ®ÐšÑ‹Ñ€Ð³Ñ‹Ð·Ñ‡Ð°LatinaLatvieÅ¡uLietuviÅ³Lingua Franca NovaMagyarÐœÐ°ÐºÐµÐ´Ð¾Ð½ÑÐºÐ¸à´®à´²à´¯à´¾à´³à´‚à¤®à¤°à¤¾à¤\xa0à¥€Bahasa Melayuê¯ƒê¯¤ê¯‡ê¯© ê¯‚ê¯£ê¯Ÿá€™á€¼á€”á€ºá€™á€¬á€˜á€¬á€žá€¬Nederlandsæ—¥æœ¬èªžNorsk bokmÃ¥lNorsk nynorskOccitanOÊ»zbekcha / ÑžÐ·Ð±ÐµÐºÑ‡Ð°à¨ªà©°à¨œà¨¾à¨¬à©€Ù¾Ù†Ø¬Ø§Ø¨ÛŒPolskiPortuguÃªsRomÃ¢nÄƒÐ\xa0ÑƒÑÑÐºÐ¸Ð¹SakizayaScotsShqipSimple EnglishSlovenÄinaÅšlÅ¯nskiÚ©ÙˆØ±Ø¯ÛŒÐ¡Ñ€Ð¿ÑÐºÐ¸ / srpskiSrpskohrvatski / ÑÑ€Ð¿ÑÐºÐ¾Ñ…Ñ€Ð²Ð°Ñ‚ÑÐºÐ¸SuomiSvenskaà®¤à®®à®¿à®´à¯Taqbaylità¹„à¸—à¸¢TÃ¼rkÃ§eÐ£ÐºÑ€Ð°Ñ—Ð½ÑÑŒÐºÐ°Ø§Ø±Ø¯ÙˆTiáº¿ng Viá»‡tWalonæ–‡è¨€Winarayå´è¯\xadç²µèªžä¸\xadæ–‡\n\nEdit links\n\n\n\n\n\n\n\n\n\n\n\nArticleTalk\n\n\n\n\n\nEnglish\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nReadEditView history\n\n\n\n\n\n\n\nTools\n\n\n\n\n\nTools\nmove to sidebar\nhide\n\n\n\n\t\tActions\n\t\n\n\nReadEditView history\n\n\n\n\n\n\t\tGeneral\n\t\n\n\nWhat links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageGet shortened URLDownload QR codeWikidata item\n\n\n\n\n\n\t\tPrint/export\n\t\n\n\nDownload as PDFPrintable version\n\n\n\n\n\n\t\tIn other projects\n\t\n\n\nWikimedia CommonsWikiquoteWikisource\n\ ...

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Priya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)
print(tokenized_word)
# Out:
# ['Alice', "'s", 'Adventures', 'in', 'Wonderland', '-', 'Wikipedia', 'Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'usDonate', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'file', 'Search', 'Search', 'Appearance', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'ContributionsTalk', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Background', 'Toggle', 'Background', 'subsection', '1.1', "''", 'All', 'in', 'the', 'golden', 'afternoon', '...', "''", '1.2', 'Manuscript', ':', 'Alice', "'s", 'Adventures', 'Under', 'Ground', '2', 'Plot', '3', 'Characters', 'Toggle', 'Characters', 'subsection', '3.1', 'Character', 'allusions', '4', 'Poems', 'and', 'songs', '5', 'Writing', 'style', 'and', 'themes', 'Toggle', 'Writing', 'style', 'and', 'themes', 'subsection', '5.1', 'Symbolism', '5.2', 'Language', '5.3', 'Mathematics', '5.4', 'Eating', 'and', 'devouring', '5.5', 'Nonsense', '5.6', 'Rules', 'and', 'games', '6', 'Illustrations', '7', 'Publication', 'history', 'Toggle', 'Publication', 'history', 'subsection', '7.1', 'Publication', 'timeline', '8', 'Reception', '9', 'Adaptations', 'and', 'influence', 'Toggle', 'Adaptations', 'and', 'influence', 'subsection', '9.1', 'Live', 'performance', '10', 'Commemoration', '11', 'See', 'also', '12', 'References', 'Toggle', 'References', 'subsection', '12.1', 'Works', 'cited', '13', 'External', 'links', 'Toggle', 'External', 'links', 'subsection', '13.1', 'Text', '13.2', 'Audio', 'Toggle', 'the', 'table', 'of', 'contents', 'Alice', "'s", 'Adventures', 'in', 'Wonderland', '94', 'languages', 'AfrikaansAlemannischÃ†ngliscØ§Ù', '„', 'Ø¹Ø±Ø¨ÙŠØ©Ô±Ö€Õ¥Ö‚Õ´Õ¿Õ¡Õ°Õ¡ÕµÕ¥Ö€Õ§Õ¶AsturianuAzÉ™rbaycancaà¦¬à¦¾à¦‚à¦²à¦¾é–©å—èªž', '/', 'BÃ¢n-lÃ¢m-gÃºÐ', '‘', 'Ð°ÑˆÒ¡Ð¾Ñ€Ñ‚ÑÐ°Ð', '‘', 'ÐµÐ', '»', 'Ð°Ñ€ÑƒÑÐºÐ°ÑÐ', '‘', 'ÐµÐ', '»', 'Ð°Ñ€ÑƒÑÐºÐ°Ñ', '(', 'Ñ‚Ð°Ñ€Ð°ÑˆÐºÐµÐ²Ñ–Ñ†Ð°', ')', 'Ð', '‘', 'ÑŠÐ', '»', 'Ð³Ð°Ñ€ÑÐºÐ¸BosanskiBrezhonegCatalÃ', 'ÄŒeÅ¡tinaCymraegDanskDeutschEestiÎ•Î', '»', 'Î', '»', 'Î·Î½Î¹ÎºÎ¬EspaÃ±olEsperantoEuskaraÙØ§Ø±Ø³ÛŒFranÃ§aisFryskGaeilgeGalegoàª—à', '«', 'àªœàª°àª¾àª¤à', '«', '€ðŒ²ðŒ¿ð', '„', 'ðŒ¹ðƒðŒºí•œêµ\xadì–´Õ€Õ¡ÕµÕ¥Ö€Õ¥Õ¶à¤¹à¤¿à¤¨à¥à¤¦à¥€HrvatskiIdoBahasa', 'IndonesiaInterlinguaÃslenskaItaliano×¢×', '‘', '×¨×™×ªà²•à²¨à³à²¨à²¡áƒ¥áƒáƒ', 'áƒ—áƒ£áƒšáƒ˜ÒšÐ°Ð·Ð°Ò›ÑˆÐ°KurdÃ®ÐšÑ‹Ñ€Ð³Ñ‹Ð·Ñ‡Ð°LatinaLatvieÅ¡uLietuviÅ³Lingua', 'Franca', 'NovaMagyarÐœÐ°ÐºÐµÐ´Ð¾Ð½ÑÐºÐ¸à´®à´²à´¯à´¾à´³à´‚à¤®à¤°à¤¾à¤', 'à¥€Bahasa', 'Melayuê¯ƒê¯¤ê¯‡ê¯©', 'ê¯‚ê¯£ê¯Ÿá€™á€¼á€', '”', 'á€ºá€™á€¬á€˜á€¬á€žá€¬Nederlandsæ—¥æœ¬èªžNorsk', 'bokmÃ¥lNorsk', 'nynorskOccitanOÊ', '»', 'zbekcha', '/', 'ÑžÐ·Ð±ÐµÐºÑ‡Ð°à¨ªà©°à¨œà¨¾à¨¬à©€Ù¾Ù†Ø¬Ø§Ø¨ÛŒPolskiPortuguÃªsRomÃ¢nÄƒÐ', 'ÑƒÑÑÐºÐ¸Ð¹SakizayaScotsShqipSimple', 'EnglishSlovenÄinaÅšlÅ¯nskiÚ©ÙˆØ±Ø¯ÛŒÐ¡Ñ€Ð¿ÑÐºÐ¸', '/', 'srpskiSrpskohrvatski', '/', 'ÑÑ€Ð¿ÑÐºÐ¾Ñ…Ñ€Ð²Ð°Ñ‚ÑÐºÐ¸SuomiSvenskaà®¤à®®à®¿à®´à¯Taqbaylità¹', '„', 'à¸—à¸¢TÃ¼rkÃ§eÐ£ÐºÑ€Ð°Ñ—Ð½ÑÑŒÐºÐ°Ø§Ø±Ø¯ÙˆTiáº¿ng', 'Viá', '»', '‡tWalonæ–‡è¨€Winarayå´è¯\xadç²µèªžä¸\xadæ–‡', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'to', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'this', 'pageGet', 'shortened', 'URLDownload', 'QR', 'codeWikidata', 'item', 'Print/export', 'Download', 'as', 'PDFPrintable', 'version', 'In', 'other', 'projects', 'Wikimedia', 'CommonsWikiquoteWikisource', 'Appearance', 'move', 'to', 'sidebar', 'hide', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', '1865', 'children', "'s", 'novel', 'by', 'Lewis', 'Carroll', "''", 'Alice', 'in', 'Wonderland', "''", 'redirects', 'here', '.', 'For', 'other', 'uses', ',', 'see', 'Alice', 'in', 'Wonderland', '(', 'di ...

# %%
from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 3208 samples and 12554 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [('.', 740),
#  (',', 536),
#  ('the', 412),
#  ('Alice', 289),
#  ('in', 268),
#  ('(', 233),
#  (')', 233),
#  ('of', 227),
#  ('[', 196),
#  (']', 196)]

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words.plot(10,cumulative = False)
plt.show()

# %%
# Defining stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {"weren't", 'd', 'shan', 'couldn', 'in', 'is', 'myself', 'again', 'that', 'here', 'why', 'not', "shouldn't", 'having', 'at', 'am', 'aren', 'there', 's', 'have', 'when', 'own', 'out', 'nor', 'do', 'mightn', 'ma', 'hasn', 'about', 'were', 'with', 'mustn', 've', 'y', 'once', 'on', "hasn't", 'to', 'itself', 'her', 'o', 'did', 'over', 'any', 'whom', 'during', 'and', 'down', 'didn', 'does', "you'll", 'those', 'other', 'll', 'where', 'its', 'herself', 'it', 'each', 'their', 'until', 'this', 'same', 'just', 'doing', 'an', 'if', 'by', 'him', 'so', 'from', 'isn', "aren't", 'themselves', 'ourselves', 'into', 'against', 'which', 'will', 'between', "isn't", 'wouldn', "that'll", 'both', 'theirs', "hadn't", "she's", 'had', 'me', 'these', 'haven', 'but', 'don', 'his', "needn't", 'below', 'doesn', 't', 'while', 'after', 'shouldn', 'been', 'before', 'above', 'few', 're', 'should', 'ain', 'she', 'because', "didn't", 'off', 'i', 'has', 'are', 'up', 'no', 'too', 'hadn', 'm', 'being', 'himself', "you'd", 'for', 'our', "you're", 'who', 'my', 'be', 'most', 'now', 'we', 'was', 'further', "should've", 'very', 'needn', 'can', 'won', 'they', 'ours', 'of', 'than', 'weren', 'what', 'wasn', 'he', 'more', 'some', 'your', 'through', "couldn't", 'yourself', 'all', "doesn't", "haven't", 'how', 'as', "don't", "mightn't", 'them', 'you', "won't", "mustn't", 'under', 'hers', 'then', "wasn't", 'yours', 'a', "shan't", 'the', 'yourselves', "it's", 'such', 'or', "wouldn't", 'only', "you've"}

# %%
# Removing stopwords in sentences
# filtered_sent = []
# for word in tokenized_sent:
#     if word not in stop_words:
#         filtered_sent.append(word)
# print(\"Tokenized Sentence:\", tokenized_sent)
# print(\"Filterd Sentence:\", filtered_sent)

# %%
# Removing stopwords in words

filtered_words = [] # creates an empty list
for word in tokenized_word:
      if word not in stop_words:
          filtered_words.append(word)

# %%
filtered_words
# Out:
# ['Alice',
#  "'s",
#  'Adventures',
#  'Wonderland',
#  '-',
#  'Wikipedia',
#  'Jump',
#  'content',
#  'Main',
#  'menu',
#  'Main',
#  'menu',
#  'move',
#  'sidebar',
#  'hide',
#  'Navigation',
#  'Main',
#  'pageContentsCurrent',
#  'eventsRandom',
#  'articleAbout',
#  'WikipediaContact',
#  'usDonate',
#  'Contribute',
#  'HelpLearn',
#  'editCommunity',
#  'portalRecent',
#  'changesUpload',
#  'file',
#  'Search',
#  'Search',
#  'Appearance',
#  'Create',
#  'account',
#  'Log',
#  'Personal',
#  'tools',
#  'Create',
#  'account',
#  'Log',
#  'Pages',
#  'logged',
#  'editors',
#  'learn',
#  'ContributionsTalk',
#  'Contents',
#  'move',
#  'sidebar',
#  'hide',
#  '(',
#  'Top',
#  ')',
#  '1',
#  'Background',
#  'Toggle',
#  'Background',
#  'subsection',
#  '1.1',
#  "''",
#  'All',
#  'golden',
#  'afternoon',
#  '...',
#  "''",
#  '1.2',
#  'Manuscript',
#  ':',
#  'Alice',
#  "'s",
#  'Adventures',
#  'Under',
#  'Ground',
#  '2',
#  'Plot',
#  '3',
#  'Characters',
#  'Toggle',
#  'Characters',
#  'subsection',
#  '3.1',
#  'Character',
#  'allusions',
#  '4',
#  'Poems',
#  'songs',
#  '5',
#  'Writing',
#  'style',
#  'themes',
#  'Toggle',
#  'Writing',
#  'style',
#  'themes',
#  'subsection',
#  '5.1',
#  'Symbolism',
#  '5.2',
#  'Language',
#  '5.3',
#  'Mathematics',
#  '5.4',
#  'Eating',
#  'devouring',
#  '5.5',
#  'Nonsense',
#  '5.6',
#  'Rules',
#  'games',
#  '6',
#  'Illustrations',
#  '7',
#  'Publication',
#  'history',
#  'Toggle',
#  'Publication',
#  'history',
#  'subsection',
#  '7.1',
#  'Publication',
#  'timeline',
#  '8',
#  'Reception',
#  '9',
#  'Adaptations',
#  'influence',
#  'Toggle',
#  'Adaptations',
#  'influence',
#  'subsection',
#  '9.1',
#  'Live',
#  'performance',
#  '10',
#  'Commemoration',
#  '11',
#  'See',
#  'also',
#  '12',
#  'References',
#  'Toggle',
#  'References',
#  'subsection',
#  '12.1',
#  'Works',
#  'cited',
#  '13',
#  'External',
#  'links',
#  'Toggle',
#  'External',
#  'links',
#  'subsection',
#  '13.1',
#  'Text',
#  '13.2',
#  'Audio',
#  'Toggle',
#  'table',
#  'contents',
#  'Alice',
#  "'s",
#  'Adventures',
#  'Wonderland',
#  '94',
#  'languages',
#  'AfrikaansAlemannischÃ†ngliscØ§Ù',
#  '„',
#  'Ø¹Ø±Ø¨ÙŠØ©Ô±Ö€Õ¥Ö‚Õ´Õ¿Õ¡Õ°Õ¡ÕµÕ¥Ö€Õ§Õ¶AsturianuAzÉ™rbaycancaà¦¬à¦¾à¦‚à¦²à¦¾é–©å—èªž',
#  '/',
#  'BÃ¢n-lÃ¢m-gÃºÐ',
#  '‘',
#  'Ð°ÑˆÒ¡Ð¾Ñ€Ñ‚ÑÐ°Ð',
#  '‘',
#  'ÐµÐ',
#  '»',
#  'Ð°Ñ€ÑƒÑÐºÐ°ÑÐ',
#  '‘',
#  'ÐµÐ',
#  '»',
#  'Ð°Ñ€ÑƒÑÐºÐ°Ñ',
#  '(',
#  'Ñ‚Ð°Ñ€Ð°ÑˆÐºÐµÐ²Ñ–Ñ†Ð°',
#  ')',
#  'Ð',
#  '‘',
#  'ÑŠÐ',
#  '»',
#  'Ð³Ð°Ñ€ÑÐºÐ¸BosanskiBrezhonegCatalÃ',
#  'ÄŒeÅ¡tinaCymraegDanskDeutschEestiÎ•Î',
#  '»',
#  'Î',
#  '»',
#  'Î·Î½Î¹ÎºÎ¬EspaÃ±olEsperantoEuskaraÙØ§Ø±Ø³ÛŒFranÃ§aisFryskGaeilgeGalegoàª—à',
#  '«',
#  'àªœàª°àª¾àª¤à',
#  '«',
#  '€ðŒ²ðŒ¿ð',
#  '„',
#  'ðŒ¹ðƒðŒºí•œêµ\xadì–´Õ€Õ¡ÕµÕ¥Ö€Õ¥Õ¶à¤¹à¤¿à¤¨à¥à¤¦à¥€HrvatskiIdoBahasa',
#  'IndonesiaInterlinguaÃslenskaItaliano×¢×',
#  '‘',
#  '×¨×™×ªà²•à²¨à³à²¨à²¡áƒ¥áƒáƒ',
#  'áƒ—áƒ£áƒšáƒ˜ÒšÐ°Ð·Ð°Ò›ÑˆÐ°KurdÃ®ÐšÑ‹Ñ€Ð³Ñ‹Ð·Ñ‡Ð°LatinaLatvieÅ¡uLietuviÅ³Lingua',
#  'Franca',
#  'NovaMagyarÐœÐ°ÐºÐµÐ´Ð¾Ð½ÑÐºÐ¸à´®à´²à´¯à´¾à´³à´‚à¤®à¤°à¤¾à¤',
#  'à¥€Bahasa',
#  'Melayuê¯ƒê¯¤ê¯‡ê¯©',
#  'ê¯‚ê¯£ê¯Ÿá€™á€¼á€',
#  '”',
#  'á€ºá€™á€¬á€˜á€¬á€žá€¬Nederlandsæ—¥æœ¬èªžNorsk',
#  'bokmÃ¥lNorsk',
#  'nynorskOccitanOÊ',
#  '»',
#  'zbekcha',
#  '/',
#  'ÑžÐ·Ð±ÐµÐºÑ‡Ð°à¨ªà©°à¨œà¨¾à¨¬à©€Ù¾Ù†Ø¬Ø§Ø¨ÛŒPolskiPortuguÃªsRomÃ¢nÄƒÐ',
#  'ÑƒÑÑÐºÐ¸Ð¹SakizayaScotsShqipSimple',
#  'EnglishSlovenÄinaÅšlÅ¯nskiÚ©ÙˆØ±Ø¯ÛŒÐ¡Ñ€Ð¿ÑÐºÐ¸',
#  '/',
#  'srpskiSrpskohrvatski',
#  '/',
#  'ÑÑ€Ð¿ÑÐºÐ¾Ñ…Ñ€Ð²Ð°Ñ‚ÑÐºÐ¸SuomiSvenskaà®¤à®®à®¿à®´à¯Taqbaylità¹',
#  '„',
#  'à¸—à¸¢TÃ¼rkÃ§eÐ£ÐºÑ€Ð°Ñ—Ð½ÑÑŒÐºÐ°Ø§Ø±Ø¯ÙˆTiáº¿ng',
#  'Viá',
#  '»',
#  '‡tWalonæ–‡è¨€Winarayå´è¯\xadç²µèªžä¸\xadæ–‡',
#  'Edit',
#  'links',
#  'ArticleTalk',
#  'English',
#  'ReadEditView',
#  'history',
#  'Tools',
#  'Tools',
#  'move',
#  'sidebar',
#  'hide',
#  'Actions',
#  'ReadEditView',
#  'history',
#  'General',
#  'What',
#  'links',
#  'hereRelated',
#  'changesUpload',
#  'fileSpecial',
#  'pagesPermanent',
#  'linkPage',
#  'informationCite',
#  'pageGet',
#  'shortened',
#  'URLDownload',
#  'QR',
#  'codeWikidata',
#  'item',
#  'Print/export',
#  'Download',
#  'PDFPrintable',
#  'version',
#  'In',
#  'projects',
#  'Wikimedia',
#  'CommonsWikiquoteWikisource',
#  'Appearance',
#  'move',
#  'sidebar',
#  'hide',
#  'From',
#  'Wikipedia',
#  ',',
#  'free',
#  'encyclopedia',
#  '1865',
#  'children',
#  "'s",
#  'novel',
#  'Lewis',
#  'Carroll',
#  "''",
#  'Alice',
#  'Wonderland',
#  "''",
#  'redirects',
#  '.',
#  'For',
#  'uses',
#  ',',
#  'see',
#  'Alice',
#  'Wonderland',
#  '(',
#  'disambiguation',
#  ')',
#  '.',
#  'Alice',
#  "'s",
#  'Adventures',
#  'Wonderland',
#  'First',
#  'edition',
#  'cover',
#  '(',
#  '1865',
#  ')',
#  'AuthorLewis',
#  'CarrollIllustratorJohn',
#  'TennielLanguageEnglishGenrePortal',
#  'fantasyLiterary',
#  'nonsensePublisherMacmillanPublication',
#  'dateNovember',
#  '1865Publication',
#  'placeUnited',
#  'KingdomFollowedÂ',
#  'byThrough',
#  'Looking-GlassÂ',
#  'TextAlice',
#  "'s",
#  'Adventures',
#  'Wonderland',
#  'Wikisource',
#  'Alice',
#  "'s",
#  'Adventures',
#  'Wonderland',
#  '(',
#  'also',
#  'known',
#  'Alice',
#  'Wonderland',
#  ')',
#  '1865',
#  'English',
#  'children',
#  "'s",
#  'novel',
#  'Lewis',
#  'Carroll',
#  ',',
#  'mathematics',
#  'University',
#  'Oxford',
#  '.',
#  'It',
#  'details',
#  'story',
#  'girl',
#  'named',
#  'Alice',
#  'falls',
#  'rabbit',
#  'hole',
#  'fantasy',
#  'world',
#  'anthropomorphic',
#  'creatures',
#  '.',
#  'It',
#  'seen',
#  'example',
#  'literary',
#  'nonsense',
#  'genre',
#  '.',
#  'The',
#  'artist',
#  'John',
#  'Tenniel',
#  'provided',
#  '42',
#  'wood-engraved',
#  'illustrations',
#  'book',
#  '.',
#  'It',
#  'received',
#  'positive',
#  'reviews',
#  'upon',
#  'release',
#  'one',
#  'best-known',
#  'works',
#  'Victorian',
#  'literature',
#  ';',
#  'narrative',
#  ',',
#  'structure',
#  ',',
#  'characters',
#  'imagery',
#  'widespread',
#  'influence',
#  'popular',
#  'culture',
#  'literature',
#  ',',
#  'especially',
#  'fantasy',
#  'genre',
#  '.',
#  '[',
#  '1',
#  ']',
#  '[',
#  '2',
#  ']',
#  'It',
#  'credited',
#  'helping',
#  'end',
#  'era',
#  'didacticism',
#  'children',
#  "'s",
#  'literature',
#  ',',
#  'inaugurating',
#  'era',
#  'writing',
#  'children',
#  'aimed',
#  '``',
#  'delight',
#  'entertain',
#  "''",
#  '.',
#  '[',
#  '3',
#  ']',
#  'The',
#  'tale',
#  'plays',
#  'logic',
#  ',',
#  'giving',
#  'story',
#  'lasting',
#  'popularity',
#  'adults',
#  'well',
#  'children',
#  '.',
#  '[',
#  '4',
#  ']',
#  'The',
#  'titular',
#  'character',
#  'Alice',
#  'shares',
#  'name',
#  'Alice',
#  'Liddell',
#  ',',
#  'girl',
#  'Carroll',
#  'knewâ€',
#  '”',
#  'scholars',
#  'disagree',
#  'extent',
#  'character',
#  'based',
#  'upon',
#  '.',
#  '[',
#  '5',
#  ']',
#  '[',
#  '6',
#  ']',
#  'The',
#  'book',
#  'never',
#  'print',
#  'translated',
#  '174',
#  'languages',
#  '.',
#  'Its',
#  'legacy',
#  'includes',
#  'adaptations',
#  'screen',
#  ',',
#  'radio',
#  ',',
#  'visual',
#  'art',
#  ',',
#  'ballet',
#  ',',
#  'opera',
#  ',',
#  'musical',
#  'theatre',
#  ',',
#  'well',
#  'theme',
#  'parks',
#  ',',
#  'board',
#  'games',
#  'video',
#  'games',
#  '.',
#  '[',
#  '7',
#  ']',
#  'Carroll',
#  'published',
#  'sequel',
#  '1871',
#  'entitled',
#  'Through',
#  'Looking-Glass',
#  'shortened',
#  'version',
#  'young',
#  'children',
#  ',',
#  'The',
#  'Nursery',
#  '``',
#  'Alice',
#  "''",
#  ',',
#  '1890',
#  '.',
#  'Background',
#  '[',
#  'edit',
#  ']',
#  "''",
#  'All',
#  'golden',
#  'afternoon',
#  '...',
#  "''",
#  '[',
#  'edit',
#  ']',
#  'Alice',
#  "'s",
#  'Adventures',
#  'Wonderland',
#  'conceived',
#  '4',
#  'July',
#  '1862',
#  ',',
#  'Lewis',
#  'Carroll',
#  'Reverend',
#  'Robinson',
#  'Duckworth',
#  'rowed',
#  'river',
#  'Isis',
#  'three',
#  'young',
#  'daughters',
#  'Carroll',
#  "'s",
#  'friend',
#  'Henry',
#  'Liddell',
#  ':',
#  '[',
#  '8',
#  ']',
#  '[',
#  '9',
#  ']',
#  'Lorina',
#  'Charlotte',
#  '(',
#  'aged',
#  '13',
#  ';',
#  '``',
#  'Prima',
#  "''",
#  'book',
#  "'s",
#  'prefatory',
#  'verse',
#  ')',
#  ';',
#  'Alice',
#  'Pleasance',
#  '(',
#  'aged',
#  '10',
#  ';',
#  '``',
#  'Secunda',
#  "''",
#  'verse',
#  ')',
#  ';',
#  'Edith',
#  'Mary',
#  '(',
#  'aged',
#  '8',
#  ';',
#  '``',
#  'Tertia',
#  "''",
#  'verse',
#  ')',
#  '.',
#  '[',
#  '10',
#  ']',
#  'The',
#  'journey',
#  'began',
#  'Folly',
#  'Bridge',
#  ',',
#  'Oxford',
#  ',',
#  'ended',
#  '5',
#  'miles',
#  '(',
#  '8Â',
#  'km',
#  ')',
#  'upstream',
#  'Godstow',
#  ',',
#  'Oxfordshire',
#  '.',
#  'During',
#  'trip',
#  ',',
#  'Carroll',
#  'told',
#  'girls',
#  'story',
#  'described',
#  'diary',
#  '``',
#  'Alice',
#  "'s",
#  'Adventures',
#  'Under',
#  'Ground',
#  "''",
#  ',',
#  'journal',
#  'says',
#  '``',
#  'undertook',
#  'write',
#  'Alice',
#  "''",
#  '.',
#  '[',
#  '11',
#  ']',
#  'Alice',
#  'Liddell',
#  'recalled',
#  'asked',
#  'Carroll',
#  'write',
#  ':',
#  'unlike',
#  'stories',
#  'told',
#  ',',
#  'one',
#  'wanted',
#  'preserve',
#  '.',
#  '[',
#  '12',
#  ']',
#  'She',
#  'finally',
#  'received',
#  'manuscript',
#  'two',
#  'years',
#  'later',
#  '.',
#  '[',
#  '13',
#  ']',
#  '4',
#  'July',
#  'known',
#  '``',
#  'golden',
#  'afternoon',
#  "''",
#  ',',
#  'prefaced',
#  'novel',
#  'poem',
#  '.',
#  '[',
#  '14',
#  ']',
#  'In',
#  'fact',
#  ',',
#  'weather',
#  'around',
#  'Oxford',
#  '4',
#  'July',
#  '``',
#  'cool',
#  'rather',
#  'wet',
#  "''",
#  ',',
#  'although',
#  'least',
#  'one',
#  'scholar',
#  'disputed',
#  'claim',
#  '.',
#  '[',
#  '15',
#  ']',
#  'Scholars',
#  'debate',
#  'whether',
#  'Carroll',
#  'fact',
#  'came',
#  'Alice',
#  '``',
#  'golden',
#  'afternoon',
#  "''",
#  'whether',
#  'story',
#  'developed',
#  'longer',
#  'period',
#  '.',
#  '[',
#  '14',
#  ']',
#  'Carroll',
#  'known',
#  'Liddell',
#  'children',
#  'since',
#  'around',
#  'March',
#  '1856',
#  ',',
#  'befriended',
#  'Harry',
#  'Liddell',
#  '.',
#  '[',
#  '16',
#  ']',
#  'He',
#  'met',
#  'Lorina',
#  'early',
#  'March',
#  'well',
#  '.',
#  '[',
#  '17',
#  ']',
#  'In',
#  'June',
#  '1856',
#  ',',
#  'took',
#  'children',
#  'river',
#  '.',
#  '[',
#  '18',
#  ']',
#  'Robert',
#  'Douglas-Fairhurst',
#  ',',
#  'wrote',
#  'literary',
#  'biography',
#  'Carroll',
#  ',',
#  'suggests',
#  'Carroll',
#  'favoured',
#  'Alice',
#  'Pleasance',
#  'Liddell',
#  'particular',
#  'name',
#  'ripe',
#  'allusion',
#  '.',
#  '[',
#  '19',
#  ']',
#  '``',
#  'Pleasance',
#  "''",
#  'means',
#  'pleasure',
#  'name',
#  '``',
#  'Alice',
#  "''",
#  'appeared',
#  'contemporary',
#  'works',
#  ',',
#  'including',
#  'poem',
#  '``',
#  'Alice',
#  'Gray',
#  "''",
#  'William',
#  'Mee',
#  ',',
#  'Carroll',
#  'wrote',
#  'parody',
#  ';',
#  'Alice',
#  'character',
#  '``',
#  'Dream-Children',
#  ':',
#  'A',
#  'Reverie',
#  "''",
#  ',',
#  'prose',
#  'piece',
#  'Charles',
#  'Lamb',
#  '.',
#  '[',
#  '19',
#  ']',
#  'Carroll',
#  ',',
#  'amateur',
#  'photographer',
#  'late',
#  '1850s',
#  ',',
#  '[',
#  '20',
#  ']',
#  'produced',
#  'many',
#  'photographic',
#  'portraits',
#  'Liddell',
#  'childrenâ€',
#  '”',
#  'none',
#  'Alice',
#  ',',
#  '20',
#  'survive',
#  '.',
#  '[',
#  '21',
#  ']',
#  'Manuscript',
#  ':',
#  'Alice',
#  "'s",
#  'Adventures',
#  'Under',
#  'Ground',
#  '[',
#  'edit',
#  ']',
#  'Page',
#  'manuscript',
#  'Alice',
#  "'s",
#  'Adventures',
#  'Under',
#  'Ground',
#  ',',
#  '1864',
#  'Carroll',
#  'began',
#  'writing',
#  'manuscript',
#  'story',
#  'next',
#  'day',
#  ',',
#  'although',
#  'earliest',
#  'version',
#  'lost',
#  '.',
#  'The',
#  'girls',
#  'Carroll',
#  'took',
#  'another',
#  'boat',
#  'trip',
#  'month',
#  'later',
#  ',',
#  'elaborated',
#  'plot',
#  'story',
#  'Alice',
#  ',',
#  'November',
#  ',',
#  'began',
#  'working',
#  'manuscript',
#  'earnest',
#  '.',
#  '[',
#  '22',
#  ']',
#  'To',
#  'add',
#  'finishing',
#  'touches',
#  'researched',
#  'natural',
#  'history',
#  'connection',
#  'animals',
#  'presented',
#  'book',
#  ',',
#  'book',
#  'examined',
#  'childrenâ€',
#  '”',
#  'particularly',
#  'George',
#  'MacDonald',
#  '.',
#  'Though',
#  'Carroll',
#  'add',
#  'illustrations',
#  'original',
#  'copy',
#  ',',
#  'publication',
#  'advised',
#  'find',
#  'professional',
#  'illustrator',
#  'pictures',
#  'appealing',
#  'audience',
#  '.',
#  'He',
#  'subsequently',
#  'approached',
#  'John',
#  'Tenniel',
#  'reinterpret',
#  'Carroll',
#  "'s",
#  'visions',
#  'artistic',
#  'eye',
#  ',',
#  'telling',
#  'story',
#  'well',
#  'liked',
#  'children',
#  '.',
#  '[',
#  '22',
#  ']',
#  'Carroll',
#  'began',
#  'planning',
#  'print',
#  'edition',
#  ...]

# %%
# Create a new FreqDist for filtered_words
dist_words_filter = FreqDist(filtered_words)
print(dist_words_filter)
# Out:
# <FreqDist with 3108 samples and 10082 outcomes>

# %%
# Frequency Distribution Plot
plt.figure(figsize=(8, 3))
dist_words_filter.plot(10, cumulative = False)
plt.show()

# %%
dist_words_filter
# Out:
# FreqDist({'.': 740, ',': 536, 'Alice': 289, '(': 233, ')': 233, '[': 196, ']': 196, "'s": 193, "''": 164, 'The': 153, ...})

# %%
# Substitute all punctuations marks with a space
sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                   " ",          # Replace all non-letters with spaces
                   str(filtered_words))

# %%
sans_punc
# Out:
# '  Alice     s    Adventures    Wonderland         Wikipedia    Jump    content    Main    menu    Main    menu    move    sidebar    hide    Navigation    Main    pageContentsCurrent    eventsRandom    articleAbout    WikipediaContact    usDonate    Contribute    HelpLearn    editCommunity    portalRecent    changesUpload    file    Search    Search    Appearance    Create    account    Log    Personal    tools    Create    account    Log    Pages    logged    editors    learn    ContributionsTalk    Contents    move    sidebar    hide         Top              Background    Toggle    Background    subsection                 All    golden    afternoon                        Manuscript         Alice     s    Adventures    Under    Ground         Plot         Characters    Toggle    Characters    subsection           Character    allusions         Poems    songs         Writing    style    themes    Toggle    Writing    style    themes    subsection           Symbolism           Language           Mathematics           Eating    devouring           Nonsense           Rules    games         Illustrations         Publication    history    Toggle    Publication    history    subsection           Publication    timeline         Reception         Adaptations    influence    Toggle    Adaptations    influence    subsection           Live    performance          Commemoration          See    also          References    Toggle    References    subsection            Works    cited          External    links    Toggle    External    links    subsection            Text            Audio    Toggle    table    contents    Alice     s    Adventures    Wonderland          languages    AfrikaansAlemannisch  nglisc                                                  AsturianuAz  rbaycanca                                B  n l  m g                                                                                                                                                                        BosanskiBrezhonegCatal       e  tinaCymraegDanskDeutschEesti                                Espa  olEsperantoEuskara         Fran  aisFryskGaeilgeGalego                                                                  xad                                  HrvatskiIdoBahasa    IndonesiaInterlingua slenskaItaliano                                                                     Kurd                  LatinaLatvie  uLietuvi  Lingua    Franca    NovaMagyar                                                       Bahasa    Melayu                                                               Nederlands         Norsk    bokm  lNorsk    nynorskOccitanO          zbekcha                                                     PolskiPortugu  sRom  n                 SakizayaScotsShqipSimple    EnglishSloven ina  l  nski                              srpskiSrpskohrvatski                                  SuomiSvenska              Taqbaylit                 T  rk  e                           Ti   ng    Vi           tWalon      Winaray     xad         xad       Edit    links    ArticleTalk    English    ReadEditView    history    Tools    Tools    move    sidebar    hide    Actions    ReadEditView    history    General    What    links    hereRelated    changesUpload    fileSpecial    pagesPermanent    linkPage    informationCite    pageGet    shortened    URLDownload    QR    codeWikidata    item    Print export    Download    PDFPrintable    version    In    projects    Wikimedia    CommonsWikiquoteWikisource    Appearance    move    sidebar    hide    From    Wikipedia         free    encyclopedia            children     s    novel    Lewis    Carroll          Alice    Wonderland          redirects         For    uses         see    Alice    Wonderland         disambiguation              Alice     s    Adventures    Wonderland    First    edition    cover                      AuthorLewis    CarrollIllustratorJohn    TennielLanguageEnglishGenrePortal    fantasyLiterary    nonsense ...

# %%
# Word tokenization
tokenized_word_2 = word_tokenize(sans_punc)
print(tokenized_word_2)
# Out:
# ['Alice', 's', 'Adventures', 'Wonderland', 'Wikipedia', 'Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'usDonate', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'file', 'Search', 'Search', 'Appearance', 'Create', 'account', 'Log', 'Personal', 'tools', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'ContributionsTalk', 'Contents', 'move', 'sidebar', 'hide', 'Top', 'Background', 'Toggle', 'Background', 'subsection', 'All', 'golden', 'afternoon', 'Manuscript', 'Alice', 's', 'Adventures', 'Under', 'Ground', 'Plot', 'Characters', 'Toggle', 'Characters', 'subsection', 'Character', 'allusions', 'Poems', 'songs', 'Writing', 'style', 'themes', 'Toggle', 'Writing', 'style', 'themes', 'subsection', 'Symbolism', 'Language', 'Mathematics', 'Eating', 'devouring', 'Nonsense', 'Rules', 'games', 'Illustrations', 'Publication', 'history', 'Toggle', 'Publication', 'history', 'subsection', 'Publication', 'timeline', 'Reception', 'Adaptations', 'influence', 'Toggle', 'Adaptations', 'influence', 'subsection', 'Live', 'performance', 'Commemoration', 'See', 'also', 'References', 'Toggle', 'References', 'subsection', 'Works', 'cited', 'External', 'links', 'Toggle', 'External', 'links', 'subsection', 'Text', 'Audio', 'Toggle', 'table', 'contents', 'Alice', 's', 'Adventures', 'Wonderland', 'languages', 'AfrikaansAlemannisch', 'nglisc', 'AsturianuAz', 'rbaycanca', 'B', 'n', 'l', 'm', 'g', 'BosanskiBrezhonegCatal', 'e', 'tinaCymraegDanskDeutschEesti', 'Espa', 'olEsperantoEuskara', 'Fran', 'aisFryskGaeilgeGalego', 'xad', 'HrvatskiIdoBahasa', 'IndonesiaInterlingua', 'slenskaItaliano', 'Kurd', 'LatinaLatvie', 'uLietuvi', 'Lingua', 'Franca', 'NovaMagyar', 'Bahasa', 'Melayu', 'Nederlands', 'Norsk', 'bokm', 'lNorsk', 'nynorskOccitanO', 'zbekcha', 'PolskiPortugu', 'sRom', 'n', 'SakizayaScotsShqipSimple', 'EnglishSloven', 'ina', 'l', 'nski', 'srpskiSrpskohrvatski', 'SuomiSvenska', 'Taqbaylit', 'T', 'rk', 'e', 'Ti', 'ng', 'Vi', 'tWalon', 'Winaray', 'xad', 'xad', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'codeWikidata', 'item', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikimedia', 'CommonsWikiquoteWikisource', 'Appearance', 'move', 'sidebar', 'hide', 'From', 'Wikipedia', 'free', 'encyclopedia', 'children', 's', 'novel', 'Lewis', 'Carroll', 'Alice', 'Wonderland', 'redirects', 'For', 'uses', 'see', 'Alice', 'Wonderland', 'disambiguation', 'Alice', 's', 'Adventures', 'Wonderland', 'First', 'edition', 'cover', 'AuthorLewis', 'CarrollIllustratorJohn', 'TennielLanguageEnglishGenrePortal', 'fantasyLiterary', 'nonsensePublisherMacmillanPublication', 'dateNovember', 'Publication', 'placeUnited', 'KingdomFollowed', 'byThrough', 'Looking', 'Glass', 'TextAlice', 's', 'Adventures', 'Wonderland', 'Wikisource', 'Alice', 's', 'Adventures', 'Wonderland', 'also', 'known', 'Alice', 'Wonderland', 'English', 'children', 's', 'novel', 'Lewis', 'Carroll', 'mathematics', 'University', 'Oxford', 'It', 'details', 'story', 'girl', 'named', 'Alice', 'falls', 'rabbit', 'hole', 'fantasy', 'world', 'anthropomorphic', 'creatures', 'It', 'seen', 'example', 'literary', 'nonsense', 'genre', 'The', 'artist', 'John', 'Tenniel', 'provided', 'wood', 'engraved', 'illustrations', 'book', 'It', 'received', 'positive', 'reviews', 'upon', 'release', 'one', 'best', 'known', 'works', 'Victorian', 'literature', 'narrative', 'structure', 'characters', 'imagery', 'widespread', 'influence', 'popular', 'culture', 'literature', 'especially', 'fantasy', 'genre', 'It', 'credited', 'helping', 'end', 'era', 'didacticism', 'children', ' ...

# %%
# Create a new FreqDist
dist_words_filter_2 = FreqDist(tokenized_word_2)

# %%
# Frequency Distribution Plot
plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(30, cumulative = False)
plt.show()

# %%
dist_words_filter_2.most_common(20)
# Out:
# [('Alice', 295),
#  ('s', 196),
#  ('The', 153),
#  ('Wonderland', 114),
#  ('Carroll', 90),
#  ('p', 72),
#  ('Adventures', 58),
#  ('original', 37),
#  ('ISBN', 36),
#  ('Retrieved', 33),
#  ('Lewis', 31),
#  ('A', 31),
#  ('pp', 30),
#  ('Archived', 29),
#  ('book', 27),
#  ('edit', 27),
#  ('OCLC', 26),
#  ('Glass', 25),
#  ('Looking', 24),
#  ('children', 23)]

# %%
## POS Tags with TextBlob
new_stopwords = ["And", "Then", 'n', 't', 's', 'The']
                
filtered = []
for word in tokenized_word_2:
        if word not in new_stopwords:
            filtered.append(word)

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: total: 0 ns
# Wall time: 37 ms

# %%
text
# Out:
# TextBlob("['Alice', 'Adventures', 'Wonderland', 'Wikipedia', 'Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'usDonate', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'file', 'Search', 'Search', 'Appearance', 'Create', 'account', 'Log', 'Personal', 'tools', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'ContributionsTalk', 'Contents', 'move', 'sidebar', 'hide', 'Top', 'Background', 'Toggle', 'Background', 'subsection', 'All', 'golden', 'afternoon', 'Manuscript', 'Alice', 'Adventures', 'Under', 'Ground', 'Plot', 'Characters', 'Toggle', 'Characters', 'subsection', 'Character', 'allusions', 'Poems', 'songs', 'Writing', 'style', 'themes', 'Toggle', 'Writing', 'style', 'themes', 'subsection', 'Symbolism', 'Language', 'Mathematics', 'Eating', 'devouring', 'Nonsense', 'Rules', 'games', 'Illustrations', 'Publication', 'history', 'Toggle', 'Publication', 'history', 'subsection', 'Publication', 'timeline', 'Reception', 'Adaptations', 'influence', 'Toggle', 'Adaptations', 'influence', 'subsection', 'Live', 'performance', 'Commemoration', 'See', 'also', 'References', 'Toggle', 'References', 'subsection', 'Works', 'cited', 'External', 'links', 'Toggle', 'External', 'links', 'subsection', 'Text', 'Audio', 'Toggle', 'table', 'contents', 'Alice', 'Adventures', 'Wonderland', 'languages', 'AfrikaansAlemannisch', 'nglisc', 'AsturianuAz', 'rbaycanca', 'B', 'l', 'm', 'g', 'BosanskiBrezhonegCatal', 'e', 'tinaCymraegDanskDeutschEesti', 'Espa', 'olEsperantoEuskara', 'Fran', 'aisFryskGaeilgeGalego', 'xad', 'HrvatskiIdoBahasa', 'IndonesiaInterlingua', 'slenskaItaliano', 'Kurd', 'LatinaLatvie', 'uLietuvi', 'Lingua', 'Franca', 'NovaMagyar', 'Bahasa', 'Melayu', 'Nederlands', 'Norsk', 'bokm', 'lNorsk', 'nynorskOccitanO', 'zbekcha', 'PolskiPortugu', 'sRom', 'SakizayaScotsShqipSimple', 'EnglishSloven', 'ina', 'l', 'nski', 'srpskiSrpskohrvatski', 'SuomiSvenska', 'Taqbaylit', 'T', 'rk', 'e', 'Ti', 'ng', 'Vi', 'tWalon', 'Winaray', 'xad', 'xad', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'codeWikidata', 'item', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikimedia', 'CommonsWikiquoteWikisource', 'Appearance', 'move', 'sidebar', 'hide', 'From', 'Wikipedia', 'free', 'encyclopedia', 'children', 'novel', 'Lewis', 'Carroll', 'Alice', 'Wonderland', 'redirects', 'For', 'uses', 'see', 'Alice', 'Wonderland', 'disambiguation', 'Alice', 'Adventures', 'Wonderland', 'First', 'edition', 'cover', 'AuthorLewis', 'CarrollIllustratorJohn', 'TennielLanguageEnglishGenrePortal', 'fantasyLiterary', 'nonsensePublisherMacmillanPublication', 'dateNovember', 'Publication', 'placeUnited', 'KingdomFollowed', 'byThrough', 'Looking', 'Glass', 'TextAlice', 'Adventures', 'Wonderland', 'Wikisource', 'Alice', 'Adventures', 'Wonderland', 'also', 'known', 'Alice', 'Wonderland', 'English', 'children', 'novel', 'Lewis', 'Carroll', 'mathematics', 'University', 'Oxford', 'It', 'details', 'story', 'girl', 'named', 'Alice', 'falls', 'rabbit', 'hole', 'fantasy', 'world', 'anthropomorphic', 'creatures', 'It', 'seen', 'example', 'literary', 'nonsense', 'genre', 'artist', 'John', 'Tenniel', 'provided', 'wood', 'engraved', 'illustrations', 'book', 'It', 'received', 'positive', 'reviews', 'upon', 'release', 'one', 'best', 'known', 'works', 'Victorian', 'literature', 'narrative', 'structure', 'characters', 'imagery', 'widespread', 'influence', 'popular', 'culture', 'literature', 'especially', 'fantasy', 'genre', 'It', 'credited', 'helping', 'end', 'era', 'didacticism', 'children', 'literature', 'inaugurating', 'era', 'writing',  ...

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Priya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('[', 'JJ'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'Jump", 'NNP'),
#  ("'", 'POS'),
#  ("'content", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Navigation", 'NN'),
#  ("'pageContentsCurrent", 'NNP'),
#  ("'", 'POS'),
#  ("'eventsRandom", 'NNP'),
#  ("'", 'POS'),
#  ("'articleAbout", 'IN'),
#  ("'WikipediaContact", 'NNP'),
#  ("'", 'POS'),
#  ("'usDonate", 'NNP'),
#  ("'", 'POS'),
#  ("'HelpLearn", 'NNP'),
#  ("'", 'POS'),
#  ("'editCommunity", 'NNP'),
#  ("'", 'POS'),
#  ("'portalRecent", 'NNP'),
#  ("'", 'POS'),
#  ("'file", 'IN'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Personal", 'NNP'),
#  ("'", 'POS'),
#  ("'tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Pages", 'NNS'),
#  ("'", 'POS'),
#  ("'logged", 'VBD'),
#  ("'editors", 'NNS'),
#  ("'", 'POS'),
#  ("'learn", 'NNP'),
#  ("'", 'POS'),
#  ("'Contents", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Background", 'IN'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Background", 'IN'),
#  ("'subsection", 'NNP'),
#  ("'", 'POS'),
#  ("'golden", 'NNP'),
#  ("'", 'POS'),
#  ("'Manuscript", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Ground", 'IN'),
#  ("'Plot", 'NNP'),
#  ("'", 'POS'),
#  ("'Characters", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Characters", 'NNS'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Character", 'NNP'),
#  ("'", 'POS'),
#  ("'allusions", 'NNS'),
#  ("'", 'POS'),
#  ("'Poems", 'NNS'),
#  ("'", 'POS'),
#  ("'songs", 'NNS'),
#  ("'", 'POS'),
#  ("'Writing", 'VBG'),
#  ("'themes", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Writing", 'VBG'),
#  ("'themes", 'NNS'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Symbolism", 'NNP'),
#  ("'", 'POS'),
#  ("'Language", 'NN'),
#  ("'Mathematics", 'NNS'),
#  ("'", 'POS'),
#  ("'Eating", 'VBG'),
#  ("'devouring", 'VBG'),
#  ("'Rules", 'NNS'),
#  ("'", 'POS'),
#  ("'games", 'NNS'),
#  ("'", 'POS'),
#  ("'Illustrations", 'NNS'),
#  ("'", 'POS'),
#  ("'Publication", 'NN'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Publication", 'NN'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Publication", 'NNP'),
#  ("'", 'POS'),
#  ("'timeline", 'NNP'),
#  ("'", 'POS'),
#  ("'Reception", 'NN'),
#  ("'Adaptations", 'NNS'),
#  ("'", 'POS'),
#  ("'influence", 'NN'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Adaptations", 'NNS'),
#  ("'", 'POS'),
#  ("'influence", 'NN'),
#  ("'subsection", 'NNP'),
#  ("'", 'POS'),
#  ("'Live", 'CD'),
#  ("'performance", 'NNP'),
#  ("'", 'POS'),
#  ("'Commemoration", 'NN'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'References", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'References", 'NNS'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Works", 'NNS'),
#  ("'", 'POS'),
#  ("'cited", 'VBD'),
#  ("'External", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'External", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Audio", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'table", 'JJ'),
#  ("'contents", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'languages", 'NNS'),
#  ("'", 'POS'),
#  ("'AfrikaansAlemannisch", 'NNP'),
#  ("'", 'POS'),
#  ("'nglisc", 'NNP'),
#  ("'", 'POS'),
#  ("'AsturianuAz", 'NNP'),
#  ("'", 'POS'),
#  ("'rbaycanca", 'NNP'),
#  ("'", 'POS'),
#  ('B', 'NNP'),
#  ("'", 'POS'),
#  ('l', 'NN'),
#  ("'m", 'VBP'),
#  ('g', 'NN'),
#  ("'BosanskiBrezhonegCatal", 'NNP'),
#  ("'", 'POS'),
#  ('e', 'NN'),
#  ("'tinaCymraegDanskDeutschEesti", 'NNP'),
#  ("'", 'POS'),
#  ("'Espa", 'NNP'),
#  ("'", 'POS'),
#  ("'olEsperantoEuskara", 'NNP'),
#  ("'", 'POS'),
#  ("'Fran", 'NNP'),
#  ("'", 'POS'),
#  ("'aisFryskGaeilgeGalego", 'NNP'),
#  ("'", 'POS'),
#  ("'xad", 'NNP'),
#  ("'", 'POS'),
#  ("'HrvatskiIdoBahasa", 'NNP'),
#  ("'", 'POS'),
#  ("'IndonesiaInterlingua", 'NNP'),
#  ("'", 'POS'),
#  ("'slenskaItaliano", 'NNP'),
#  ("'", 'POS'),
#  ("'Kurd", 'NNP'),
#  ("'", 'POS'),
#  ("'LatinaLatvie", 'NNP'),
#  ("'", 'POS'),
#  ("'uLietuvi", 'NNP'),
#  ("'", 'POS'),
#  ("'Lingua", 'NNP'),
#  ("'", 'POS'),
#  ("'Franca", 'NNP'),
#  ("'", 'POS'),
#  ("'NovaMagyar", 'NNP'),
#  ("'", 'POS'),
#  ("'Bahasa", 'NNP'),
#  ("'", 'POS'),
#  ("'Melayu", 'NNP'),
#  ("'", 'POS'),
#  ("'Nederlands", 'NNS'),
#  ("'", 'POS'),
#  ("'Norsk", 'NNP'),
#  ("'", 'POS'),
#  ("'bokm", 'NNP'),
#  ("'", 'POS'),
#  ("'lNorsk", 'NNP'),
#  ("'", 'POS'),
#  ("'nynorskOccitanO", 'NNP'),
#  ("'", 'POS'),
#  ("'zbekcha", 'NNP'),
#  ("'", 'POS'),
#  ("'PolskiPortugu", 'NNP'),
#  ("'", 'POS'),
#  ("'sRom", 'NNP'),
#  ("'", 'POS'),
#  ("'ina", 'NNP'),
#  ("'", 'POS'),
#  ('l', 'NN'),
#  ("'nski", 'NNP'),
#  ("'", 'POS'),
#  ("'srpskiSrpskohrvatski", 'NNP'),
#  ("'", 'POS'),
#  ("'SuomiSvenska", 'NNP'),
#  ("'", 'POS'),
#  ("'Taqbaylit", 'NNP'),
#  ("'", 'POS'),
#  ("'T", 'NNP'),
#  ("'", 'POS'),
#  ("'rk", 'NNP'),
#  ("'", 'POS'),
#  ('e', 'NN'),
#  ("'Ti", 'NNP'),
#  ("'", 'POS'),
#  ("'ng", 'NNP'),
#  ("'", 'POS'),
#  ("'Vi", 'NNP'),
#  ("'", 'POS'),
#  ("'tWalon", 'NNP'),
#  ("'", 'POS'),
#  ("'xad", 'NNP'),
#  ("'", 'POS'),
#  ("'xad", 'NNP'),
#  ("'", 'POS'),
#  ("'Edit", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Actions", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'General", 'NNP'),
#  ("'", 'POS'),
#  ("'What", 'WP'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'hereRelated", 'VBD'),
#  ("'fileSpecial", 'NNP'),
#  ("'", 'POS'),
#  ("'pagesPermanent", 'NNP'),
#  ("'", 'POS'),
#  ("'linkPage", 'NN'),
#  ("'informationCite", 'NNP'),
#  ("'", 'POS'),
#  ("'shortened", 'VBD'),
#  ("'QR", 'NNP'),
#  ("'", 'POS'),
#  ("'codeWikidata", 'NNP'),
#  ("'", 'POS'),
#  ("'item", 'NNP'),
#  ("'", 'POS'),
#  ("'Print", 'NNP'),
#  ("'", 'POS'),
#  ("'export", 'NNP'),
#  ("'", 'POS'),
#  ("'PDFPrintable", 'JJ'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'projects", 'NNS'),
#  ("'", 'POS'),
#  ("'Wikimedia", 'NNP'),
#  ("'", 'POS'),
#  ("'CommonsWikiquoteWikisource", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'encyclopedia", 'NNP'),
#  ("'", 'POS'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'novel", 'NNP'),
#  ("'", 'POS'),
#  ("'Lewis", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'redirects", 'NNS'),
#  ("'", 'POS'),
#  ("'For", 'NNP'),
#  ("'", 'POS'),
#  ("'uses", 'NNS'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'disambiguation", 'NN'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'edition", 'NN'),
#  ("'AuthorLewis", 'NNP'),
#  ("'", 'POS'),
#  ("'CarrollIllustratorJohn", 'NNP'),
#  ("'", 'POS'),
#  ("'TennielLanguageEnglishGenrePortal", 'NNP'),
#  ("'", 'POS'),
#  ("'fantasyLiterary", 'NNP'),
#  ("'", 'POS'),
#  ("'nonsensePublisherMacmillanPublication", 'NN'),
#  ("'dateNovember", 'NNP'),
#  ("'", 'POS'),
#  ("'Publication", 'NN'),
#  ("'placeUnited", 'VBD'),
#  ("'KingdomFollowed", 'VBD'),
#  ("'byThrough", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'TextAlice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'Wikisource", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'novel", 'NNP'),
#  ("'", 'POS'),
#  ("'Lewis", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'mathematics", 'NNS'),
#  ("'", 'POS'),
#  ("'University", 'NNP'),
#  ("'", 'POS'),
#  ("'Oxford", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'details", 'NNS'),
#  ("'", 'POS'),
#  ("'story", 'NNP'),
#  ("'", 'POS'),
#  ("'girl", 'NNP'),
#  ("'", 'POS'),
#  ("'named", 'VBD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'falls", 'NNS'),
#  ("'", 'POS'),
#  ("'hole", 'NNP'),
#  ("'", 'POS'),
#  ("'fantasy", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'anthropomorphic", 'NNP'),
#  ("'", 'POS'),
#  ("'creatures", 'NNS'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'literary", 'NNP'),
#  ("'", 'POS'),
#  ("'genre", 'NNP'),
#  ("'", 'POS'),
#  ("'John", 'NNP'),
#  ("'", 'POS'),
#  ("'Tenniel", 'NNP'),
#  ("'", 'POS'),
#  ("'provided", 'VBD'),
#  ("'wood", 'NNP'),
#  ("'", 'POS'),
#  ("'engraved", 'VBD'),
#  ("'illustrations", 'NNS'),
#  ("'", 'POS'),
#  ("'book", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'received", 'VBD'),
#  ("'positive", 'CD'),
#  ("'reviews", 'NNS'),
#  ("'", 'POS'),
#  ("'release", 'NNP'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'best", 'JJS'),
#  ("'works", 'NNS'),
#  ("'", 'POS'),
#  ("'Victorian", 'JJ'),
#  ("'literature", 'NN'),
#  ("'narrative", 'CD'),
#  ("'structure", 'NN'),
#  ("'characters", 'NNS'),
#  ("'", 'POS'),
#  ("'imagery", 'NNP'),
#  ("'", 'POS'),
#  ("'influence", 'NNP'),
#  ("'", 'POS'),
#  ("'culture", 'NN'),
#  ("'literature", 'NN'),
#  ("'especially", 'RB'),
#  ("'", 'POS'),
#  ("'fantasy", 'NNP'),
#  ("'", 'POS'),
#  ("'genre", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'credited", 'VBD'),
#  ("'helping", 'VBG'),
#  ("'didacticism", 'NNP'),
#  ("'", 'POS'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'literature", 'NN'),
#  ("'inaugurating", 'VBG'),
#  ("'writing", 'VBG'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'aimed", 'VBD'),
#  ("'delight", 'NNP'),
#  ("'", 'POS'),
#  ("'tale", 'NNP'),
#  ("'", 'POS'),
#  ("'plays", 'NNS'),
#  ("'", 'POS'),
#  ("'logic", 'NNP'),
#  ("'", 'POS'),
#  ("'giving", 'VBG'),
#  ("'story", 'NNP'),
#  ("'", 'POS'),
#  ("'lasting", 'VBG'),
#  ("'popularity", 'NNP'),
#  ("'", 'POS'),
#  ("'adults", 'NNS'),
#  ("'", 'POS'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'character", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'shares", 'NNS'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Liddell", 'NNP'),
#  ("'", 'POS'),
#  ("'girl", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'knew", 'NNP'),
#  ("'", 'POS'),
#  ("'scholars", 'NNS'),
#  ("'", 'POS'),
#  ("'extent", 'NNP'),
#  ("'", 'POS'),
#  ("'character", 'NNP'),
#  ("'", 'POS'),
#  ("'based", 'VBD'),
#  ("'book", 'NNP'),
#  ("'", 'POS'),
#  ("'print", 'NNP'),
#  ("'", 'POS'),
#  ("'translated", 'VBD'),
#  ("'languages", 'NNS'),
#  ("'", 'POS'),
#  ("'Its", 'NNP'),
#  ("'", 'POS'),
#  ("'legacy", 'NNP'),
#  ("'", 'POS'),
#  ("'includes", 'NNS'),
#  ("'", 'POS'),
#  ("'adaptations", 'NNS'),
#  ("'", 'POS'),
#  ("'radio", 'NNP'),
#  ("'", 'POS'),
#  ("'visual", 'JJ'),
#  ("'art", 'NNP'),
#  ("'", 'POS'),
#  ("'ballet", 'NNP'),
#  ("'", 'POS'),
#  ("'musical", 'JJ'),
#  ("'theatre", 'NNP'),
#  ("'", 'POS'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'parks", 'NNS'),
#  ("'", 'POS'),
#  ("'board", 'NNP'),
#  ("'", 'POS'),
#  ("'games", 'NNS'),
#  ("'", 'POS'),
#  ("'video", 'NNP'),
#  ("'", 'POS'),
#  ("'games", 'NNS'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'published", 'VBD'),
#  ("'sequel", 'NNP'),
#  ("'", 'POS'),
#  ("'entitled", 'VBD'),
#  ("'Through", 'IN'),
#  ("'Looking", 'VBG'),
#  ("'Glass", 'NNP'),
#  ("'", 'POS'),
#  ("'shortened", 'VBD'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'young", 'NNP'),
#  ("'", 'POS'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'Nursery", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Background", 'IN'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'golden", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Wonderland", 'NNP'),
#  ("'", 'POS'),
#  ("'conceived", 'VBD'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'Lewis", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'Robinson", 'NNP'),
#  ("'", 'POS'),
#  ("'rowed", 'VBD'),
#  ("'young", 'NNP'),
#  ("'", 'POS'),
#  ("'daughters", 'NNS'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'Henry", 'NNP'),
#  ("'", 'POS'),
#  ("'Liddell", 'NNP'),
#  ("'", 'POS'),
#  ("'Lorina", 'NNP'),
#  ("'", 'POS'),
#  ("'Charlotte", 'NNP'),
#  ("'", 'POS'),
#  ("'aged", 'VBD'),
#  ("'Prima", 'NNP'),
#  ("'", 'POS'),
#  ("'book", 'NNP'),
#  ("'", 'POS'),
#  ("'prefatory", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Pleasance", 'NN'),
#  ("'aged", 'VBD'),
#  ("'Secunda", 'NNP'),
#  ("'", 'POS'),
#  ("'Edith", 'NNP'),
#  ("'", 'POS'),
#  ("'Mary", 'NNP'),
#  ("'", 'POS'),
#  ("'aged", 'VBD'),
#  ("'Tertia", 'NNP'),
#  ("'", 'POS'),
#  ("'journey", 'NNP'),
#  ("'", 'POS'),
#  ("'began", 'NNP'),
#  ("'", 'POS'),
#  ("'Folly", 'RB'),
#  ("'", 'POS'),
#  ("'Bridge", 'NNP'),
#  ("'", 'POS'),
#  ("'Oxford", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'miles", 'NNS'),
#  ("'", 'POS'),
#  ("'km", 'NNP'),
#  ("'", 'POS'),
#  ("'Godstow", 'NNP'),
#  ("'", 'POS'),
#  ("'Oxfordshire", 'NNP'),
#  ("'", 'POS'),
#  ("'During", 'VBG'),
#  ("'trip", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'girls", 'NNP'),
#  ("'", 'POS'),
#  ("'story", 'NNP'),
#  ("'", 'POS'),
#  ("'diary", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Ground", 'IN'),
#  ("'journal", 'NNP'),
#  ("'", 'POS'),
#  ("'says", 'NNS'),
#  ("'", 'POS'),
#  ("'undertook", 'NNP'),
#  ("'", 'POS'),
#  ("'write", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Liddell", 'NNP'),
#  ("'", 'POS'),
#  ("'recalled", 'VBD'),
#  ("'asked", 'VBD'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'write", 'NNP'),
#  ("'", 'POS'),
#  ("'unlike", 'IN'),
#  ("'stories", 'NNS'),
#  ("'", 'POS'),
#  ("'one", 'CD'),
#  ("'wanted", 'VBD'),
#  ("'preserve", 'NNP'),
#  ("'", 'POS'),
#  ("'She", 'NNP'),
#  ("'", 'POS'),
#  ("'finally", 'RB'),
#  ("'", 'POS'),
#  ("'received", 'VBD'),
#  ("'manuscript", 'NNP'),
#  ("'", 'POS'),
#  ("'two", 'NNP'),
#  ("'", 'POS'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'later", 'NNP'),
#  ("'", 'POS'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'golden", 'NNP'),
#  ("'", 'POS'),
#  ("'prefaced", 'VBD'),
#  ("'novel", 'NNP'),
#  ("'", 'POS'),
#  ("'poem", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'fact", 'NNP'),
#  ("'", 'POS'),
#  ("'weather", 'PRP'),
#  ("'around", 'IN'),
#  ("'Oxford", 'NNP'),
#  ("'", 'POS'),
#  ("'July", 'NNP'),
#  ("'", 'POS'),
#  ("'cool", 'NNP'),
#  ("'", 'POS'),
#  ("'rather", 'PRP'),
#  ("'wet", 'NNP'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'one", 'CD'),
#  ("'disputed", 'VBD'),
#  ("'claim", 'NNP'),
#  ("'", 'POS'),
#  ("'Scholars", 'NNS'),
#  ("'", 'POS'),
#  ("'debate", 'NNP'),
#  ("'", 'POS'),
#  ("'whether", 'PRP'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'fact", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'golden", 'NNP'),
#  ("'", 'POS'),
#  ("'whether", 'PRP'),
#  ("'story", 'NNP'),
#  ("'", 'POS'),
#  ("'developed", 'VBD'),
#  ("'longer", 'NNP'),
#  ("'", 'POS'),
#  ("'period", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'Liddell", 'NNP'),
#  ("'", 'POS'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'since", 'NN'),
#  ("'around", 'IN'),
#  ("'March", 'NNP'),
#  ("'", 'POS'),
#  ("'befriended", 'VBD'),
#  ("'Harry", 'NNP'),
#  ("'", 'POS'),
#  ("'Liddell", 'NNP'),
#  ("'", 'POS'),
#  ("'He", 'NNP'),
#  ("'", 'POS'),
#  ("'met", 'NNP'),
#  ("'", 'POS'),
#  ("'Lorina", 'NNP'),
#  ("'", 'POS'),
#  ("'early", 'RB'),
#  ("'March", 'NNP'),
#  ("'", 'POS'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'June", 'NNP'),
#  ("'", 'POS'),
#  ("'took", 'NNP'),
#  ("'", 'POS'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'Robert", 'NNP'),
#  ("'", 'POS'),
#  ("'Douglas", 'NNS'),
#  ("'", 'POS'),
#  ("'Fairhurst", 'NNP'),
#  ("'", 'POS'),
#  ("'literary", 'NNP'),
#  ("'", 'POS'),
#  ("'biography", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'suggests", 'NNS'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'favoured", 'VBD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Pleasance", 'NN'),
#  ("'Liddell", 'NNP'),
#  ("'", 'POS'),
#  ("'ripe", 'NNP'),
#  ("'", 'POS'),
#  ("'allusion", 'NN'),
#  ("'Pleasance", 'NNP'),
#  ("'", 'POS'),
#  ("'means", 'NNS'),
#  ("'", 'POS'),
#  ("'pleasure", 'NN'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'appeared", 'VBD'),
#  ("'contemporary", 'NNP'),
#  ("'", 'POS'),
#  ("'works", 'NNS'),
#  ("'", 'POS'),
#  ("'including", 'VBG'),
#  ("'poem", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'William", 'NNP'),
#  ("'", 'POS'),
#  ("'Mee", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'parody", 'NN'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'character", 'NNP'),
#  ("'", 'POS'),
#  ("'Children", 'NNP'),
#  ("'", 'POS'),
#  ('A', 'NNP'),
#  ("'", 'POS'),
#  ("'Reverie", 'NNP'),
#  ("'", 'POS'),
#  ("'prose", 'NNP'),
#  ("'", 'POS'),
#  ("'piece", 'NNP'),
#  ("'", 'POS'),
#  ("'Charles", 'NNS'),
#  ("'", 'POS'),
#  ("'Lamb", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'photographer", 'PRP'),
#  ("'late", 'NNP'),
#  ("'", 'POS'),
#  ("'produced", 'VBD'),
#  ("'", 'POS'),
#  ("'photographic", 'NNP'),
#  ("'", 'POS'),
#  ("'portraits", 'NNS'),
#  ("'", 'POS'),
#  ("'Liddell", 'NNP'),
#  ("'", 'POS'),
#  ("'children", 'NNP'),
#  ("'", 'POS'),
#  ("'none", 'CD'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'survive", 'CD'),
#  ("'Manuscript", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Ground", 'IN'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'Page", 'NN'),
#  ("'manuscript", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'Adventures", 'NNS'),
#  ("'", 'POS'),
#  ("'Ground", 'IN'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'began", 'NNP'),
#  ("'", 'POS'),
#  ("'writing", 'VBG'),
#  ("'manuscript", 'NNP'),
#  ("'", 'POS'),
#  ("'story", 'NNP'),
#  ("'", 'POS'),
#  ("'although", 'IN'),
#  ("'earliest", 'JJS'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'lost", 'FW'),
#  ("'", 'POS'),
#  ("'girls", 'NNP'),
#  ("'", 'POS'),
#  ("'Carroll", 'NNP'),
#  ("'", 'POS'),
#  ("'took", 'NNP'),
#  ("'", 'POS'),
#  ("'another", 'PRP'),
#  ("'boat", 'NNP'),
#  ("'", 'POS'),
#  ("'trip", 'NNP'),
#  ("'", 'POS'),
#  ("'later", 'NNP'),
#  ("'", 'POS'),
#  ("'elaborated", 'VBD'),
#  ("'plot", 'NNP'),
#  ("'", 'POS'),
#  ("'story", 'NNP'),
#  ("'", 'POS'),
#  ("'Alice", 'NNP'),
#  ("'", 'POS'),
#  ("'November", 'NNP'),
#  ("'", 'POS'),
#  ("'began", 'NNP'),
#  ("'", 'POS'),
#  ("'working", 'VBG'),
#  ("'manuscript", 'NNP'),
#  ("'", 'POS'),
#  ("'earnest", 'JJS'),
#  ("'To", 'NNP'),
#  ("'", 'POS'),
#  ("'add", 'NNP'),
#  ("'", 'POS'),
#  ("'finishing", 'VBG'),
#  ...]

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = ['Words', "Word type"]

# %%
df_text.head()
# Out:
#          Words Word type
# 0            [        JJ
# 1       'Alice       NNP
# 2            '       POS
# 3  'Adventures       NNS
# 4            '       POS

# %%
df_t = df_text.groupby('Word type').count().reset_index()

# %%
df_t.head()
# Out:
#   Word type  Words
# 0        CC      3
# 1        CD     42
# 2        DT      5
# 3        EX      6
# 4        FW     10

# %%
top20 = df_t.nlargest(20, 'Words')

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 20):
        sns.barplot(x = "Words", y = "Word type",
        saturation = 0.9, data = top20).set_title("Alice in Wonderland - top 20 word types used")

# %%
#### Nouns
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNP")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top10 = y.nlargest(10, 'Occurences')

# %%
top10
# Out:
#              Word  Occurences
# 21         'Alice         295
# 932   'Wonderland         114
# 130      'Carroll          90
# 1840            p          72
# 13    'Adventures          58
# 1472    'original          37
# 389         'ISBN          36
# 477        'Lewis          31
# 1817            A          31
# 1536          'pp          30

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("xkcd:blue", 10):
        sns.barplot(x="Word", y="Occurences",
        saturation=0.9, data = top10).set_title("Alice in Wonderland - most frequently used nouns")

# %%
#### Verbs
df = df_text[(df_text['Word type'] == "VB")  | (df_text['Word type'] == "VBD")]
df.columns = ["Word", "Occurences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurences'], ascending=False)
top10 = y.nlargest(10, 'Occurences')

# %%
top10
# Out:
#              Word  Occurences
# 16     'Retrieved          33
# 2       'Archived          29
# 109    'published          10
# 140   'translated           8
# 111     'received           8
# 79      'inspired           7
# 31         'based           7
# 77   'illustrated           6
# 1      'Annotated           6
# 13     'Published           6

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 10):
    sns.barplot(x = "Word", y = "Occurences",
    saturation = 0.9, data = top10).set_title("Alice in Wonderland - most frequently used verbs")

# %%
## Counting character occurences
listToStr = ' '.join([str(elem) for elem in filtered])

print(listToStr)
# Out:
# Alice Adventures Wonderland Wikipedia Jump content Main menu Main menu move sidebar hide Navigation Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate Contribute HelpLearn editCommunity portalRecent changesUpload file Search Search Appearance Create account Log Personal tools Create account Log Pages logged editors learn ContributionsTalk Contents move sidebar hide Top Background Toggle Background subsection All golden afternoon Manuscript Alice Adventures Under Ground Plot Characters Toggle Characters subsection Character allusions Poems songs Writing style themes Toggle Writing style themes subsection Symbolism Language Mathematics Eating devouring Nonsense Rules games Illustrations Publication history Toggle Publication history subsection Publication timeline Reception Adaptations influence Toggle Adaptations influence subsection Live performance Commemoration See also References Toggle References subsection Works cited External links Toggle External links subsection Text Audio Toggle table contents Alice Adventures Wonderland languages AfrikaansAlemannisch nglisc AsturianuAz rbaycanca B l m g BosanskiBrezhonegCatal e tinaCymraegDanskDeutschEesti Espa olEsperantoEuskara Fran aisFryskGaeilgeGalego xad HrvatskiIdoBahasa IndonesiaInterlingua slenskaItaliano Kurd LatinaLatvie uLietuvi Lingua Franca NovaMagyar Bahasa Melayu Nederlands Norsk bokm lNorsk nynorskOccitanO zbekcha PolskiPortugu sRom SakizayaScotsShqipSimple EnglishSloven ina l nski srpskiSrpskohrvatski SuomiSvenska Taqbaylit T rk e Ti ng Vi tWalon Winaray xad xad Edit links ArticleTalk English ReadEditView history Tools Tools move sidebar hide Actions ReadEditView history General What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite pageGet shortened URLDownload QR codeWikidata item Print export Download PDFPrintable version In projects Wikimedia CommonsWikiquoteWikisource Appearance move sidebar hide From Wikipedia free encyclopedia children novel Lewis Carroll Alice Wonderland redirects For uses see Alice Wonderland disambiguation Alice Adventures Wonderland First edition cover AuthorLewis CarrollIllustratorJohn TennielLanguageEnglishGenrePortal fantasyLiterary nonsensePublisherMacmillanPublication dateNovember Publication placeUnited KingdomFollowed byThrough Looking Glass TextAlice Adventures Wonderland Wikisource Alice Adventures Wonderland also known Alice Wonderland English children novel Lewis Carroll mathematics University Oxford It details story girl named Alice falls rabbit hole fantasy world anthropomorphic creatures It seen example literary nonsense genre artist John Tenniel provided wood engraved illustrations book It received positive reviews upon release one best known works Victorian literature narrative structure characters imagery widespread influence popular culture literature especially fantasy genre It credited helping end era didacticism children literature inaugurating era writing children aimed delight entertain tale plays logic giving story lasting popularity adults well children titular character Alice shares name Alice Liddell girl Carroll knew scholars disagree extent character based upon book never print translated languages Its legacy includes adaptations screen radio visual art ballet opera musical theatre well theme parks board games video games Carroll published sequel entitled Through Looking Glass shortened version young children Nursery Alice Background edit All golden afternoon edit Alice Adventures Wonderland conceived July Lewis Carroll Reverend Robinson Duckworth rowed river Isis three young daughters Carroll friend Henry Liddell Lorina Charlotte aged Prima book prefatory verse Alice Pleasance aged Secunda verse Edith Mary aged Tertia verse journey began Folly Bridge Oxford ended miles km upstream Godstow Oxfordshire During trip Carroll told girls story described diary Alice Adventures Under Ground journal says undertook write Alice Alice Liddell recalled asked Carro ...

# %%
# Create a count for the main characters
all_counts = Counter(re.sub(r'\\W+', ' ', listToStr).split())

# %%
all_counts
# Out:
# Counter({'Alice': 295,
#          'Wonderland': 114,
#          'Carroll': 90,
#          'p': 72,
#          'Adventures': 58,
#          'original': 37,
#          'ISBN': 36,
#          'Retrieved': 33,
#          'Lewis': 31,
#          'A': 31,
#          'pp': 30,
#          'Archived': 29,
#          'book': 27,
#          'edit': 27,
#          'OCLC': 26,
#          'Glass': 25,
#          'Looking': 24,
#          'children': 23,
#          'Through': 23,
#          'January': 23,
#          'story': 20,
#          'Liddell': 20,
#          'Queen': 20,
#          'New': 20,
#          'fantasy': 18,
#          'first': 18,
#          'Press': 18,
#          'b': 18,
#          'University': 17,
#          'English': 16,
#          'edition': 16,
#          'Tenniel': 16,
#          'Hearts': 16,
#          'Gardner': 16,
#          'In': 15,
#          'Hatter': 15,
#          'identifiersArticles': 15,
#          'Under': 14,
#          'Ground': 14,
#          'John': 14,
#          'March': 14,
#          'Douglas': 14,
#          'White': 14,
#          'York': 14,
#          'manuscript': 13,
#          'Fairhurst': 13,
#          'Cohen': 13,
#          'illustrations': 12,
#          'Children': 12,
#          'May': 12,
#          'Mad': 12,
#          'Cheshire': 12,
#          'December': 12,
#          'Books': 12,
#          'September': 12,
#          'Fantasy': 12,
#          'Oxford': 11,
#          'Victorian': 11,
#          'musical': 11,
#          'July': 11,
#          'November': 11,
#          'Macmillan': 11,
#          'London': 11,
#          'also': 10,
#          'It': 10,
#          'nonsense': 10,
#          'literature': 10,
#          'published': 10,
#          'parody': 10,
#          'British': 10,
#          'Guardian': 10,
#          'Jaques': 10,
#          'Giddens': 10,
#          'All': 9,
#          'world': 9,
#          'one': 9,
#          'characters': 9,
#          'writing': 9,
#          'Robert': 9,
#          'wrote': 9,
#          'Tea': 9,
#          'Rabbit': 9,
#          'play': 9,
#          'sold': 9,
#          'World': 9,
#          'fiction': 9,
#          'Toggle': 8,
#          'received': 8,
#          'works': 8,
#          'translated': 8,
#          'Gray': 8,
#          'Party': 8,
#          'Duchess': 8,
#          'time': 8,
#          'Turtle': 8,
#          'new': 8,
#          'work': 8,
#          'th': 8,
#          'Carpenter': 8,
#          'Royal': 8,
#          'ISSN': 8,
#          'doi': 8,
#          'ed': 8,
#          'Literature': 8,
#          'subsection': 7,
#          'history': 7,
#          'links': 7,
#          'version': 7,
#          'name': 7,
#          'based': 7,
#          'print': 7,
#          'opera': 7,
#          'young': 7,
#          'around': 7,
#          'He': 7,
#          'publication': 7,
#          'Mock': 7,
#          'House': 7,
#          'language': 7,
#          'public': 7,
#          'April': 7,
#          'inspired': 7,
#          'c': 7,
#          'Magic': 7,
#          'Wikipedia': 6,
#          'golden': 6,
#          'afternoon': 6,
#          'Characters': 6,
#          'Publication': 6,
#          'known': 6,
#          'literary': 6,
#          'tale': 6,
#          'character': 6,
#          'ballet': 6,
#          'animals': 6,
#          'copy': 6,
#          'Library': 6,
#          'Cat': 6,
#          'like': 6,
#          'King': 6,
#          'Annotated': 6,
#          'Martin': 6,
#          'song': 6,
#          'Star': 6,
#          'Little': 6,
#          'Twinkle': 6,
#          'Taylor': 6,
#          'Beer': 6,
#          'mouse': 6,
#          'century': 6,
#          'I': 6,
#          'illustrated': 6,
#          'Published': 6,
#          'J': 6,
#          'books': 6,
#          'American': 6,
#          'film': 6,
#          'West': 6,
#          'production': 6,
#          'February': 6,
#          'Lost': 6,
#          'Main': 5,
#          'games': 5,
#          'influence': 5,
#          'T': 5,
#          'novel': 5,
#          'girl': 5,
#          'named': 5,
#          'popular': 5,
#          'well': 5,
#          'told': 5,
#          'She': 5,
#          'poem': 5,
#          'including': 5,
#          'late': 5,
#          'suggested': 5,
#          'door': 5,
#          'meets': 5,
#          'Caterpillar': 5,
#          'series': 5,
#          'Mouse': 5,
#          'Dodo': 5,
#          'Gladstone': 5,
#          'L': 5,
#          'white': 5,
#          'Susina': 5,
#          'rules': 5,
#          'run': 5,
#          'Publishers': 5,
#          'Appleton': 5,
#          'domain': 5,
#          'd': 5,
#          'publishes': 5,
#          'adaptation': 5,
#          'Time': 5,
#          'Opera': 5,
#          'novels': 5,
#          'Times': 5,
#          'S': 5,
#          'Project': 5,
#          'Publishing': 5,
#          'Gutenberg': 5,
#          'move': 4,
#          'sidebar': 4,
#          'hide': 4,
#          'account': 4,
#          'songs': 4,
#          'style': 4,
#          'themes': 4,
#          'Works': 4,
#          'table': 4,
#          'e': 4,
#          'xad': 4,
#          'What': 4,
#          'era': 4,
#          'never': 4,
#          'sequel': 4,
#          'Lorina': 4,
#          'verse': 4,
#          'began': 4,
#          'says': 4,
#          'two': 4,
#          'years': 4,
#          'although': 4,
#          'scholar': 4,
#          'Harry': 4,
#          'William': 4,
#          'Charles': 4,
#          'page': 4,
#          'facsimile': 4,
#          'finds': 4,
#          'bottle': 4,
#          'size': 4,
#          'fan': 4,
#          'Race': 4,
#          'house': 4,
#          'make': 4,
#          'Hare': 4,
#          'Dormouse': 4,
#          'party': 4,
#          'tree': 4,
#          'cards': 4,
#          'short': 4,
#          'Gryphon': 4,
#          'Lobster': 4,
#          'Beautiful': 4,
#          'Pat': 4,
#          'Carter': 4,
#          'Tale': 4,
#          'Dodgson': 4,
#          'may': 4,
#          'One': 4,
#          'C': 4,
#          'How': 4,
#          'Old': 4,
#          'David': 4,
#          'rose': 4,
#          'red': 4,
#          'life': 4,
#          'child': 4,
#          'de': 4,
#          'food': 4,
#          'Bivona': 4,
#          'printed': 4,
#          'US': 4,
#          'copies': 4,
#          'illustrators': 4,
#          'Company': 4,
#          'list': 4,
#          'French': 4,
#          'Le': 4,
#          'stage': 4,
#          'Theatre': 4,
#          'music': 4,
#          'Ballet': 4,
#          'Translations': 4,
#          'Jones': 4,
#          'set': 4,
#          'St': 4,
#          'History': 4,
#          'Routledge': 4,
#          'Blunderland': 4,
#          'Science': 4,
#          'using': 4,
#          'Background': 3,
#          'Manuscript': 3,
#          'Character': 3,
#          'Poems': 3,
#          'Writing': 3,
#          'Language': 3,
#          'Mathematics': 3,
#          'timeline': 3,
#          'Adaptations': 3,
#          'Live': 3,
#          'performance': 3,
#          'References': 3,
#          'External': 3,
#          'Text': 3,
#          'languages': 3,
#          'item': 3,
#          'uses': 3,
#          'see': 3,
#          'rabbit': 3,
#          'hole': 3,
#          'creatures': 3,
#          'example': 3,
#          'genre': 3,
#          'provided': 3,
#          'upon': 3,
#          'best': 3,
#          'didacticism': 3,
#          'aimed': 3,
#          'includes': 3,
#          'adaptations': 3,
#          'screen': 3,
#          'theatre': 3,
#          'video': 3,
#          'Nursery': 3,
#          'three': 3,
#          'Henry': 3,
#          'aged': 3,
#          'Pleasance': 3,
#          'Edith': 3,
#          'ended': 3,
#          'During': 3,
#          'diary': 3,
#          'later': 3,
#          'came': 3,
#          'since': 3,
#          'met': 3,
#          'suggests': 3,
#          'particular': 3,
#          'means': 3,
#          'many': 3,
#          'another': 3,
#          'date': 3,
#          'Christmas': 3,
#          'Child': 3,
#          'Day': 3,
#          'key': 3,
#          'labelled': 3,
#          'small': 3,
#          'eats': 3,
#          'causes': 3,
#          'leaves': 3,
#          'away': 3,
#          'appears': 3,
#          'orders': 3,
#          'trial': 3,
#          'riddle': 3,
#          'raven': 3,
#          'desk': 3,
#          'croquet': 3,
#          'used': 3,
#          'act': 3,
#          'When': 3,
#          'Soup': 3,
#          'Knave': 3,
#          'sister': 3,
#          'List': 3,
#          'Bill': 3,
#          'Lizard': 3,
#          'Theophilus': 3,
#          'chapter': 3,
#          'sisters': 3,
#          'Disraeli': 3,
#          'Lion': 3,
#          'Unicorn': 3,
#          'little': 3,
#          'These': 3,
#          'This': 3,
#          'called': 3,
#          'adventures': 3,
#          'Doth': 3,
#          'Crocodile': 3,
#          'You': 3,
#          'Are': 3,
#          'M': 3,
#          'painting': 3,
#          'N': 3,
#          'Beyond': 3,
#          'roses': 3,
#          'According': 3,
#          'Wars': 3,
#          'full': 3,
#          'Gillian': 3,
#          'words': 3,
#          'readers': 3,
#          'Straley': 3,
#          'role': 3,
#          'O': 3,
#          'noun': 3,
#          'case': 3,
#          'ablative': 3,
#          'Greek': 3,
#          'Melanie': 3,
#          'Bayley': 3,
#          'magazine': 3,
#          'Curious': 3,
#          'idea': 3,
#          'eat': 3,
#          'eaten': 3,
#          'entering': 3,
#          'Daniel': 3,
#          'Illustrators': 3,
#          'There': 3,
#          'significant': 3,
#          'Peter': 3,
#          'Helen': 3,
#          'publisher': 3,
#          'August': 3,
#          'Richard': 3,
#          'Clay': 3,
#          'binding': 3,
#          'title': 3,
#          'UK': 3,
#          'versions': 3,
#          'Award': 3,
#          'events': 3,
#          'Philip': 3,
#          'Kurt': 3,
#          'auction': 3,
#          'Original': 3,
#          'reading': 3,
#          'No': 3,
#          'F': 3,
#          'different': 3,
#          'England': 3,
#          'television': 3,
#          'no': 3,
#          'End': 3,
#          'faithful': 3,
#          'premiered': 3,
#          'Tom': 3,
#          'Waits': 3,
#          'glass': 3,
#          'church': 3,
#          'Warrington': 3,
#          'International': 3,
#          'statue': 3,
#          'Kelly': 3,
#          'Brown': 3,
#          'Gordon': 3,
#          'JSTOR': 3,
#          'Pudney': 3,
#          'Vol': 3,
#          'Cambridge': 3,
#          'Catherine': 3,
#          'X': 3,
#          'Adventure': 3,
#          'Biography': 3,
#          'More': 3,
#          'Norton': 3,
#          'An': 3,
#          'Society': 3,
#          'Television': 3,
#          'Mirror': 3,
#          'Texas': 3,
#          'LibriVox': 3,
#          'Red': 3,
#          'Jabberwocky': 3,
#          'Related': 3,
#          'Land': 3,
#          'Malice': 3,
#          'Dark': 3,
#          'Fairy': 3,
#          'Weird': 3,
#          'R': 3,
#          'fandom': 3,
#          'Tolkien': 3,
#          'adapted': 3,
#          'menu': 2,
#          'changesUpload': 2,
#          'Search': 2,
#          'Appearance': 2,
#          'Create': 2,
#          'Log': 2,
#          'Plot': 2,
#          'allusions': 2,
#          'Symbolism': 2,
#          'Eating': 2,
#          'devouring': 2,
#          'Nonsense': 2,
#          'Rules': 2,
#          'Illustrations': 2,
#          'Reception': 2,
#          'Commemoration': 2,
#          'See': 2,
#          'cited': 2,
#          'Audio': 2,
#          'contents': 2,
#          'B': 2,
#          'l': 2,
#          'm': 2,
#          'ReadEditView': 2,
#          'Tools': 2,
#          'shortened': 2,
#          'projects': 2,
#          'Wikimedia': 2,
#          'From': 2,
#          'cover': 2,
#          'mathematics': 2,
#          'details': 2,
#          'artist': 2,
#          'wood': 2,
#          'engraved': 2,
#          'release': 2,
#          'imagery': 2,
#          'culture': 2,
#          'end': 2,
#          'inaugurating': 2,
#          'delight': 2,
#          'entertain': 2,
#          'plays': 2,
#          'logic': 2,
#          'adults': 2,
#          'extent': 2,
#          'Its': 2,
#          'art': 2,
#          'theme': 2,
#          'entitled': 2,
#          'Robinson': 2,
#          'Duckworth': 2,
#          'river': 2,
#          'Charlotte': 2,
#          'prefatory': 2,
#          'Mary': 2,
#          'journey': 2,
#          'trip': 2,
#          'girls': 2,
#          'write': 2,
#          'asked': 2,
#          'stories': 2,
#          'finally': 2,
#          'fact': 2,
#          'rather': 2,
#          'whether': 2,
#          'period': 2,
#          'early': 2,
#          'took': 2,
#          'Dream': 2,
#          'produced': 2,
#          'next': 2,
#          'add': 2,
#          'presented': 2,
#          'George': 2,
#          'MacDonald': 2,
#          'illustrator': 2,
#          'appealing': 2,
#          'audience': 2,
#          'family': 2,
#          'publish': 2,
#          'specimen': 2,
#          'gave': 2,
#          'episodes': 2,
#          'appear': 2,
#          'room': 2,
#          'garden': 2,
#          'discovers': 2,
#          'drinks': 2,
#          'shrinks': 2,
#          'enough': 2,
#          'grow': 2,
#          'tears': 2,
#          'gloves': 2,
#          'pool': 2,
#          'bank': 2,
#          'Caucus': 2,
#          'cat': 2,
#          'go': 2,
#          'eventually': 2,
#          'allowing': 2,
#          'forest': 2,
#          'mushroom': 2,
#          'bite': 2,
#          'side': 2,
#          'After': 2,
#          'home': 2,
#          'leaving': 2,
#          'tea': 2,
#          'always': 2,
#          'still': 2,
#          'trying': 2,
#          'Why': 2,
#          'beginning': 2,
#          'turns': 2,
#          'whose': 2,
#          'guard': 2,
#          'constantly': 2,
#          'beheading': 2,
#          'impossible': 2,
#          'Quadrille': 2,
#          'sings': 2,
#          'composed': 2,
#          'previously': 2,
#          'frequent': 2,
#          'Although': 2,
#          'Further': 2,
#          'information': 2,
#          'following': 2,
#          'Lory': 2,
#          'Eaglet': 2,
#          'Duck': 2,
#          'Puppy': 2,
#          'furniture': 2,
#          'dealer': 2,
#          'model': 2,
#          'last': 2,
#          'Benjamin': 2,
#          'depicts': 2,
#          'Man': 2,
#          'look': 2,
#          'reference': 2,
#          'Elsie': 2,
#          'Lacie': 2,
#          'Tillie': 2,
#          'old': 2,
#          'week': 2,
#          'teach': 2,
#          'critic': 2,
#          'Evening': 2,
#          'Isaac': 2,
#          'Watts': 2,
#          'nursery': 2,
#          'rhyme': 2,
#          'poetry': 2,
#          'Father': 2,
#          'Speak': 2,
#          'Bat': 2,
#          'Voice': 2,
#          'James': 2,
#          'illustration': 2,
#          'Morton': 2,
#          'real': 2,
#          'even': 2,
#          'Jan': 2,
#          'argues': 2,
#          'mistreatment': 2,
#          'people': 2,
#          'parodies': 2,
#          'focus': 2,
#          'terms': 2,
#          'Jessica': 2,
#          'pun': 2,
#          'pomme': 2,
#          'apple': 2,
#          'Latin': 2,
#          'six': 2,
#          'traditional': 2,
#          'mus': 2,
#          'standard': 2,
#          'As': 2,
#          'mathematical': 2,
#          'Literary': 2,
#          'Scientist': 2,
#          'Garland': 2,
#          'Appetites': 2,
#          'eating': 2,
#          'Boe': 2,
#          'Birns': 2,
#          'could': 2,
#          'worm': 2,
#          'becomes': 2,
#          'Nina': 2,
#          'Auerbach': 2,
#          'drinking': 2,
#          'Lovell': 2,
#          'Smith': 2,
#          'states': 2,
#          'way': 2,
#          'Humphrey': 2,
#          'meet': 2,
#          'non': 2,
#          'quality': 2,
#          'reprinted': 2,
#          'drawings': 2,
#          'Other': 2,
#          'include': 2,
#          'Arthur': 2,
#          'Graham': 2,
#          'Anthony': 2,
#          'Browne': 2,
#          'Oxenbury': 2,
#          'October': 2,
#          'His': 2,
#          'possibly': 2,
#          'engaged': 2,
#          'basis': 2,
#          'released': 2,
#          'quickly': 2,
#          'publishing': 2,
#          'Oscar': 2,
#          'Wilde': 2,
#          'reportedly': 2,
#          'enjoyed': 2,
#          'copyright': 2,
#          'expired': 2,
#          'Since': 2,
#          'intimately': 2,
#          'tied': 2,
#          'objection': 2,
#          'reviewers': 2,
#          'major': 2,
#          'German': 2,
#          'Found': 2,
#          'Retold': 2,
#          'Words': 2,
#          'Syllable': 2,
#          'en': 2,
#          'buyer': 2,
#          'win': 2,
#          'Maschler': 2,
#          'light': 2,
#          'dress': 2,
#          'Walter': 2,
#          'Disney': 2,
#          'McCrum': 2,
#          'perhaps': 2,
#          'famous': 2,
#          'recognised': 2,
#          'cultural': 2,
#          'icons': 2,
#          'Films': 2,
#          'silent': 2,
#          'included': 2,
#          'dauntless': 2,
#          'heroine': 2,
#          'numerous': 2,
#          'Musical': 2,
#          'Lennon': 2,
#          'Japan': 2,
#          'inspiration': 2,
#          'Japanese': 2,
#          'fashion': 2,
#          'played': 2,
#          'frequently': 2,
#          'revived': 2,
#          'Eva': 2,
#          'Gallienne': 2,
#          'Olivia': 2,
#          'Havilland': 2,
#          'Joseph': 2,
#          'Papp': 2,
#          'staged': 2,
#          'Public': 2,
#          'City': 2,
#          'Swados': 2,
#          'Festival': 2,
#          'Humpty': 2,
#          'Dumpty': 2,
#          'Paul': 2,
#          'Horovitz': 2,
#          'commissioned': 2,
#          'performed': 2,
#          'Wheeldon': 2,
#          'Nicholas': 2,
#          'Opernwelt': 2,
#          'Saints': 2,
#          'Daresbury': 2,
#          'Park': 2,
#          'Adelaide': 2,
#          'stamps': 2,
#          'Mail': 2,
#          'anniversary': 2,
#          'Down': 2,
#          'Lecercle': 2,
#          'Ray': 2,
#          'Green': 2,
#          'ProQuest': 2,
#          'CID': 2,
#          'Schwab': 2,
#          'Stan': 2,
#          'Maryland': 2,
#          'Hahn': 2,
#          'Muir': 2,
#          'Bloomsbury': 2,
#          'Weaver': 2,
#          'Marill': 2,
#          'Madness': 2,
#          'Rare': 2,
#          'Life': 2,
#          'Guiliano': 2,
#          'Guide': 2,
#          'BBC': 2,
#          'Turner': 2,
#          'Nichols': 2,
#          'Film': 2,
#          'Zoe': 2,
#          'Eugene': 2,
#          'view': 2,
#          'Sheff': 2,
#          'Monden': 2,
#          'Visual': 2,
#          'Journey': 2,
#          'Point': 2,
#          'Encyclopedia': 2,
#          'Collingwood': 2,
#          'Amor': 2,
#          'Sheehy': 2,
#          'We': 2,
#          'Her': 2,
#          'mezzo': 2,
#          'tv': 2,
#          'Secret': 2,
#          'Donald': 2,
#          'W': 2,
#          'Virginia': 2,
#          'Companion': 2,
#          'H': 2,
#          'Stage': 2,
#          'Scarecrow': 2,
#          'Last': 2,
#          'Place': 2,
#          'Austin': 2,
#          'Wisconsin': 2,
#          'audiobook': 2,
#          'Minor': 2,
#          'Tweedledum': 2,
#          'Tweedledee': 2,
#          'Unbirthday': 2,
#          'sword': 2,
#          'Hunting': 2,
#          'Snark': 2,
#          'Comics': 2,
#          'Murderland': 2,
#          'Come': 2,
#          'TV': 2,
#          'Fire': 2,
#          'module': 2,
#          'Category': 2,
#          'Hard': 2,
#          'Magical': 2,
#          'Earth': 2,
#          'romance': 2,
#          'Urban': 2,
#          'Occult': 2,
#          'detective': 2,
#          'Fiction': 2,
#          'Fantastic': 2,
#          'Locus': 2,
#          'Mythopoeic': 2,
#          'Dragons': 2,
#          'novelsBritish': 2,
#          'Articles': 2,
#          'Use': 2,
#          'Sister': 2,
#          'project': 2,
#          'Privacy': 2,
#          'Jump': 1,
#          'content': 1,
#          'Navigation': 1,
#          'pageContentsCurrent': 1,
#          'eventsRandom': 1,
#          'articleAbout': 1,
#          'WikipediaContact': 1,
#          'usDonate': 1,
#          'Contribute': 1,
#          'HelpLearn': 1,
#          'editCommunity': 1,
#          'portalRecent': 1,
#          'file': 1,
#          'Personal': 1,
#          'tools': 1,
#          'Pages': 1,
#          'logged': 1,
#          'editors': 1,
#          'learn': 1,
#          'ContributionsTalk': 1,
#          'Contents': 1,
#          'Top': 1,
#          'AfrikaansAlemannisch': 1,
#          'nglisc': 1,
#          'AsturianuAz': 1,
#          'rbaycanca': 1,
#          'g': 1,
#          'BosanskiBrezhonegCatal': 1,
#          'tinaCymraegDanskDeutschEesti': 1,
#          'Espa': 1,
#          'olEsperantoEuskara': 1,
#          'Fran': 1,
#          'aisFryskGaeilgeGalego': 1,
#          'HrvatskiIdoBahasa': 1,
#          'IndonesiaInterlingua': 1,
#          'slenskaItaliano': 1,
#          'Kurd': 1,
#          'LatinaLatvie': 1,
#          'uLietuvi': 1,
#          'Lingua': 1,
#          'Franca': 1,
#          'NovaMagyar': 1,
#          'Bahasa': 1,
#          'Melayu': 1,
#          'Nederlands': 1,
#          'Norsk': 1,
#          'bokm': 1,
#          'lNorsk': 1,
#          'nynorskOccitanO': 1,
#          'zbekcha': 1,
#          'PolskiPortugu': 1,
#          'sRom': 1,
#          'SakizayaScotsShqipSimple': 1,
#          'EnglishSloven': 1,
#          'ina': 1,
#          'nski': 1,
#          'srpskiSrpskohrvatski': 1,
#          'SuomiSvenska': 1,
#          'Taqbaylit': 1,
#          'rk': 1,
#          'Ti': 1,
#          'ng': 1,
#          'Vi': 1,
#          'tWalon': 1,
#          'Winaray': 1,
#          'Edit': 1,
#          'ArticleTalk': 1,
#          'Actions': 1,
#          'General': 1,
#          'hereRelated': 1,
#          'fileSpecial': 1,
#          'pagesPermanent': 1,
#          'linkPage': 1,
#          'informationCite': 1,
#          'pageGet': 1,
#          'URLDownload': 1,
#          'QR': 1,
#          'codeWikidata': 1,
#          'Print': 1,
#          'export': 1,
#          'Download': 1,
#          'PDFPrintable': 1,
#          'CommonsWikiquoteWikisource': 1,
#          'free': 1,
#          'encyclopedia': 1,
#          'redirects': 1,
#          'For': 1,
#          'disambiguation': 1,
#          'First': 1,
#          'AuthorLewis': 1,
#          'CarrollIllustratorJohn': 1,
#          'TennielLanguageEnglishGenrePortal': 1,
#          'fantasyLiterary': 1,
#          'nonsensePublisherMacmillanPublication': 1,
#          'dateNovember': 1,
#          'placeUnited': 1,
#          'KingdomFollowed': 1,
#          'byThrough': 1,
#          'TextAlice': 1,
#          'Wikisource': 1,
#          'falls': 1,
#          'anthropomorphic': 1,
#          'seen': 1,
#          'positive': 1,
#          'reviews': 1,
#          'narrative': 1,
#          'structure': 1,
#          'widespread': 1,
#          'especially': 1,
#          'credited': 1,
#          'helping': 1,
#          'giving': 1,
#          'lasting': 1,
#          'popularity': 1,
#          'titular': 1,
#          'shares': 1,
#          'knew': 1,
#          'scholars': 1,
#          'disagree': 1,
#          'legacy': 1,
#          'radio': 1,
#          'visual': 1,
#          'parks': 1,
#          'board': 1,
#          'conceived': 1,
#          'Reverend': 1,
#          'rowed': 1,
#          'Isis': 1,
#          'daughters': 1,
#          'friend': 1,
#          'Prima': 1,
#          'Secunda': 1,
#          'Tertia': 1,
#          'Folly': 1,
#          'Bridge': 1,
#          'miles': 1,
#          'km': 1,
#          'upstream': 1,
#          'Godstow': 1,
#          'Oxfordshire': 1,
#          'described': 1,
#          'journal': 1,
#          'undertook': 1,
#          'recalled': 1,
#          'unlike': 1,
#          'wanted': 1,
#          'preserve': 1,
#          'prefaced': 1,
#          'weather': 1,
#          'cool': 1,
#          'wet': 1,
#          'least': 1,
#          ...})

# %%
chars = pd.read_csv("Alice_characters.csv", index_col = 0)

# %%
chars.head()
# Out:
#           character
# 0             Alice
# 1  The White Rabbit
# 2         The Mouse
# 3          The Dodo
# 4          The Lory

# %%
# Replace names with aliases
chars['character'] = chars['character'].replace('Bill the Lizard','Bill')
chars['character'] = chars['character'].replace('The Queen of Hearts','Queen')
chars['character'] = chars['character'].replace('The King of Hearts','King')
chars['character'] = chars['character'].replace('The Knave of Hearts','Knave')

# %%
chars
# Out:
#            character
# 0              Alice
# 1   The White Rabbit
# 2          The Mouse
# 3           The Dodo
# 4           The Lory
# 5         The Eaglet
# 6           The Duck
# 7                Pat
# 8               Bill
# 9              Puppy
# 10   The Caterpillar
# 11       The Duchess
# 12  The Cheshire Cat
# 13        The Hatter
# 14    The March Hare
# 15      The Dormouse
# 16             Queen
# 17              King
# 18             Knave
# 19       The Gryphon
# 20   The Mock Turtle

# %%
chars['character_alias'] = chars['character'].apply(lambda x: x.rsplit(' ', 1)[-1])

# %%
chars
# Out:
#            character character_alias
# 0              Alice           Alice
# 1   The White Rabbit          Rabbit
# 2          The Mouse           Mouse
# 3           The Dodo            Dodo
# 4           The Lory            Lory
# 5         The Eaglet          Eaglet
# 6           The Duck            Duck
# 7                Pat             Pat
# 8               Bill            Bill
# 9              Puppy           Puppy
# 10   The Caterpillar     Caterpillar
# 11       The Duchess         Duchess
# 12  The Cheshire Cat             Cat
# 13        The Hatter          Hatter
# 14    The March Hare            Hare
# 15      The Dormouse        Dormouse
# 16             Queen           Queen
# 17              King            King
# 18             Knave           Knave
# 19       The Gryphon         Gryphon
# 20   The Mock Turtle          Turtle

# %%
char_list = chars['character_alias'].to_list()

# %%
dict_of_counts = {d : all_counts[d] for d in char_list}

# %%
dict_of_counts
# Out:
# {'Alice': 295,
#  'Rabbit': 9,
#  'Mouse': 5,
#  'Dodo': 5,
#  'Lory': 2,
#  'Eaglet': 2,
#  'Duck': 2,
#  'Pat': 4,
#  'Bill': 3,
#  'Puppy': 2,
#  'Caterpillar': 5,
#  'Duchess': 8,
#  'Cat': 6,
#  'Hatter': 15,
#  'Hare': 4,
#  'Dormouse': 4,
#  'Queen': 20,
#  'King': 6,
#  'Knave': 3,
#  'Gryphon': 4,
#  'Turtle': 8}

# %%
# Search for the names from the list in the dictionary
dct = {v:[k] for v,k in dict_of_counts.items()}
df = pd.DataFrame(dct)

# %%
df
# Out:
#    Alice  Rabbit  Mouse  Dodo  Lory  Eaglet  Duck  Pat  Bill  Puppy  ...  \
# 0    295       9      5     5     2       2     2    4     3      2  ...
#
#    Duchess  Cat  Hatter  Hare  Dormouse  Queen  King  Knave  Gryphon  Turtle
# 0        8    6      15     4         4     20     6      3        4       8
#
# [1 rows x 21 columns]

# %%
df = df.transpose().reset_index()

# %%
df.dtypes
# Out:
# index    object
# 0         int64
# dtype: object

# %%
df
# Out:
#           index    0
# 0         Alice  295
# 1        Rabbit    9
# 2         Mouse    5
# 3          Dodo    5
# 4          Lory    2
# 5        Eaglet    2
# 6          Duck    2
# 7           Pat    4
# 8          Bill    3
# 9         Puppy    2
# 10  Caterpillar    5
# 11      Duchess    8
# 12          Cat    6
# 13       Hatter   15
# 14         Hare    4
# 15     Dormouse    4
# 16        Queen   20
# 17         King    6
# 18        Knave    3
# 19      Gryphon    4
# 20       Turtle    8

# %%
df.rename(columns = {"index":"Character", 0:"Times mentioned"}, inplace = True)

# %%
df
# Out:
#       Character  Times mentioned
# 0         Alice              295
# 1        Rabbit                9
# 2         Mouse                5
# 3          Dodo                5
# 4          Lory                2
# 5        Eaglet                2
# 6          Duck                2
# 7           Pat                4
# 8          Bill                3
# 9         Puppy                2
# 10  Caterpillar                5
# 11      Duchess                8
# 12          Cat                6
# 13       Hatter               15
# 14         Hare                4
# 15     Dormouse                4
# 16        Queen               20
# 17         King                6
# 18        Knave                3
# 19      Gryphon                4
# 20       Turtle                8

# %%
df.shape
# Out:
# (21, 2)

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("#79C", 27):
        sns.barplot(x = "Times mentioned", y = "Character",
        saturation=0.9, data = df.sort_values("Times mentioned", ascending = False)).set_title("Alice in Wonderland - most frequently mentioned characters")

# %%
chars.to_csv("characters_alice.csv")

# %%
## Sentiment Analysis
text_sent = TextBlob(str(filtered))

# %%
print(text_sent.sentiment)
# Out:
# Sentiment(polarity=0.09144480785842034, subjectivity=0.42319408727785734)
