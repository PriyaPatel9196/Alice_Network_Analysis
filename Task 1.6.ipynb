# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------- -------------------------------- 2.4/12.8 MB 19.2 MB/s eta 0:00:01
#      -------------------------------- ------ 10.7/12.8 MB 33.6 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 32.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\priya\anaconda3\envs\venv_alice\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module
NER = spacy.load("en_core_web_sm")

# %%
# Load the book
with open('Alice_article_Wiki.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')
book = NER(data)

# %%
# Visualize identified entities
displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ð‘ÐµÐ»Ð°Ñ€ÑƒÑÐºÐ°ÑÐ‘ÐµÐ»Ð°Ñ€ÑƒÑÐºÐ°Ñ (Ñ‚Ð°Ñ€Ð°ÑˆÐºÐµÐ²Ñ–Ñ†Ð°)Ð‘ÑŠÐ»Ð³Ð°Ñ€ÑÐºÐ¸BosanskiBrezhonegCatalÃ
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ÄŒeÅ¡tinaCymraegDanskDeutschEestiÎ•Î»Î»Î·Î½Î¹ÎºÎ¬EspaÃ±olEsperantoEuskaraÙØ§Ø±Ø³ÛŒFranÃ§aisFryskGaeilgeGalegoàª—à«àªœàª
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# °àª¾àª¤à«€ðŒ²ðŒ¿ð„ðŒ¹ðƒðŒºí•œêµ­ì–´Õ€Õ¡ÕµÕ¥Ö€Õ¥Õ¶à¤¹à¤¿à¤¨à¥à¤
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ¦
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# à¥€HrvatskiIdoBahasa IndonesiaInterlinguaÃslenskaItaliano×¢×‘×¨×™×ªà²•à²¨à³à²¨à²¡áƒ¥áƒáƒ áƒ—áƒ£áƒšáƒ˜ÒšÐ°Ð·Ð°
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ò›ÑˆÐ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# °KurdÃ®ÐšÑ‹Ñ€Ð³Ñ‹Ð·Ñ‡Ð°
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LatinaLatvieÅ¡uLietuviÅ³Lingua Franca NovaMagyarÐœÐ°ÐºÐµÐ´Ð¾Ð½ÑÐºÐ¸à´
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ®à´²à´¯à´¾à´³à´‚à¤®à¤°à¤¾à¤
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     à¥€Bahasa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melayuê¯ƒê¯¤ê¯‡ê¯
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# © ê¯‚ê¯£ê¯Ÿá€™á€¼á€”á€ºá€™á€¬á€˜á€¬á€žá€¬Nederlandsæ—¥æœ¬èªžNorsk
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bokmÃ¥lNorsk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  nynorskOccitanOÊ»zbekcha / ÑžÐ·Ð±ÐµÐºÑ‡Ð°à¨ªà©°à¨œà¨¾à¨¬à©€Ù¾Ù†Ø¬Ø§Ø¨ÛŒPolskiPortuguÃªsRomÃ¢nÄƒÐ ÑƒÑÑÐºÐ¸Ð¹SakizayaScotsShqipSimple
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EnglishSlovenÄinaÅšlÅ¯nskiÚ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ©ÙˆØ±Ø¯ÛŒÐ¡Ñ€Ð¿ÑÐºÐ¸ / srpskiSrpskohrvatski / ÑÑ€Ð¿ÑÐºÐ¾Ñ…Ñ€Ð²Ð°Ñ‚ÑÐºÐ¸SuomiSvenskaà®¤à®®à®¿à®´à¯Taqbaylità¹„à¸—à¸¢TÃ¼rkÃ§eÐ£ÐºÑ€Ð°Ñ—Ð½ÑÑŒÐºÐ°Ø§Ø±Ø¯ÙˆTiáº¿ng Viá»‡tWalonæ–‡è¨€Winarayå´è¯­ç²µèªžä¸­æ–‡
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  links
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ArticleTalk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# English                  ReadEditView history        Tools      Tools move to sidebar hide    		Actions 	   ReadEditView history      		General 	   What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageGet shortened
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     URLDownload
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  QR codeWikidata item
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Print
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# /export
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Download
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PDFPrintable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  version      		In other projects 	   Wikimedia CommonsWikiquoteWikisource                      Appearance move to sidebar hide           From Wikipedia, the free encyclopedia
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1865
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  children's novel by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lewis Carroll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  &quot;Alice in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot; redirects here. For other uses, see
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (disambiguation).
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's Adventures in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem

# %%
## Get named entity list per sentence
df_sentences = [] # empty shell to store results
# Loop through sentences, get entity list for each sentence
for sent in book.sents:
       entity_list = [ent.text for ent in sent.ents]
       df_sentences.append({"sentence": sent, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (    , Alice, 's, Adventures, in, Wonderland, ...
# 1                     (à¥€Bahasa, Melayuê¯ƒê¯¤ê¯‡ê¯)
# 2  (©, ê¯‚ê¯£ê¯Ÿá€, ™, á€¼á€”á€ºá€, ™, á€¬á€˜á€¬á...
# 3  (©, ÙˆØ±Ø¯ÛŒÐ¡Ñ€Ð¿ÑÐºÐ¸, /, srpskiSrpskohrvats...
# 4  (informationCite, this, pageGet, shortened, UR...
# 5  (For, other, uses, ,, see, Alice, in, Wonderla...
# 6  (Alice, 's, Adventures, in, Wonderland, First,...
# 7  (It, details, the, story, of, a, girl, named, ...
# 8  (It, is, seen, as, an, example, of, the, liter...
# 9  (The, artist, John, Tenniel, provided, 42, woo...
#
#                                             entities
# 0  [Wonderland - Wikipedia                       ...
# 1                     [à¥€Bahasa, Melayuê¯ƒê¯¤ê¯‡ê¯]
# 2        [bokmÃ¥lNorsk, EnglishSlovenÄinaÅšlÅ¯nskiÚ]
# 3                          [Edit, ArticleTalk      ]
# 4  [URLDownload, Print, Download, PDFPrintable, 1...
# 5                                [Alice, Wonderland]
# 6  [Alice, Wonderland First, 1865)AuthorLewis, 18...
# 7                                            [Alice]
# 8                                                 []
# 9                                 [John Tenniel, 42]

# %%
## Load character names
# Import characters
character_df = pd.read_csv("characters_alice.csv", index_col = 0)

# %%
character_df.head()
# Out:
#           character character_alias
# 0             Alice           Alice
# 1  The White Rabbit          Rabbit
# 2         The Mouse           Mouse
# 3          The Dodo            Dodo
# 4          The Lory            Lory

# %%
## Filtering entities from the book
# Function to filter out entities not of interest
def filter_entity(ent_list, character_df):
       return [ent for ent in ent_list
                  if ent in list(character_df['character_alias'])]

# %%
# Check
filter_entity(["Alice", "CF", "2"], character_df)
# Out:
# ['Alice']

# %%
df_sentences['character_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, character_df))

# %%
df_sentences['character_entities'].head(20)
# Out:
# 0            [Alice]
# 1                 []
# 2                 []
# 3                 []
# 4                 []
# 5            [Alice]
# 6     [Alice, Alice]
# 7            [Alice]
# 8                 []
# 9                 []
# 10                []
# 11                []
# 12                []
# 13           [Alice]
# 14                []
# 15                []
# 16                []
# 17                []
# 18                []
# 19           [Alice]
# Name: character_entities, dtype: object

# %%
# Filter out sentences that don’t have any character entities
df_sentences_filtered = df_sentences[df_sentences['character_entities'].map(len) > 0]

# %%
df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 858                (Alice, in, Wonderland, (, 1966, ))
# 862  (Alice, through, the, Looking, Glass, (, 1998, ))
# 863                (Alice, in, Wonderland, (, 1999, ))
# 864                                (Alice, (, 2009, ))
# 866  (Alice, 's, Wonderland, Bakery, (, 2022, ), De...
# 868  (Alice, in, Wonderland, (, 2010, ), Almost, Al...
# 869                (Alice, in, Wonderland, (, 1985, ))
# 874  (Alice, in, Wonderland, (, 2000, ), American, ...
# 875  (Alice, in, the, Country, of, Hearts, (, 2007, ))
# 876                (Alice, in, Wonderland, (, 2010, ))
#
#                                               entities character_entities
# 858                                [Alice, Wonderland]            [Alice]
# 862                                      [Alice, 1998]            [Alice]
# 863                                [Alice, Wonderland]            [Alice]
# 864                                      [Alice, 2009]            [Alice]
# 866             [Alice, Wonderland Bakery, 2022, 1967]            [Alice]
# 868  [Alice, Wonderland, 2010, Almost Alice, 2010, ...            [Alice]
# 869                          [Alice, Wonderland, 1985]            [Alice]
# 874  [Alice, Wonderland, 2000, American, McGee, Alice]     [Alice, Alice]
# 875                                            [Alice]            [Alice]
# 876                          [Alice, Wonderland, 2010]            [Alice]

# %%
## Create relationships
# Defining relationships
# window size = 5 : this defines how many sentences will be looked at simultaneously
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    char_list = sum((df_sentences_filtered.loc[i: end_i].character_entities), [])

# Remove duplicated characters that are next to each other
char_unique = [char_list[i] for i in range(len(char_list))
    if (i==0) or char_list[i] != char_list[i-1]]
if len(char_unique) >1:
    for idx, a in enumerate( char_unique[ :-1]):
        b = char_unique[idx + 1]
        relationship.append({"source": a, "target": b})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 6
#       1 ## Create relationships
#       2 # Defining relationships
#       3 # window size = 5 : this defines how many sentences will be looked at simultaneously
#       4 relationships = [] # create an empty list
# ----> 6 for i in range(df_sentences_filtered.index[-1]):
#       7     end_i = min(i+5, df_sentences_filtered.index[-1])
#       8     char_list = sum((df_sentences_filtered.loc[i: end_i].character_entities), [])
#
# NameError: name 'df_sentences_filtered' is not defined

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Sort the cases with a- >b and b- >a
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Summarize the interactions
relationships_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

relationship_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[166], line 3
#       1 # Summarize the interactions
#       2 relationships_df["value"] = 1
# ----> 3 relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()
#       5 relationship_df.head(10)
#
# File ~\anaconda3\envs\venv_alice\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~\anaconda3\envs\venv_alice\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\anaconda3\envs\venv_alice\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'source'
